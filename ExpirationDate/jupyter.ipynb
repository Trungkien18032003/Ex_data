# %%
# %pip install datasets
# Out:
# Requirement already satisfied: datasets in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (3.0.0)
# Requirement already satisfied: filelock in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from datasets) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from datasets) (4.66.5)
# Requirement already satisfied: xxhash in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.2.0)
# Requirement already satisfied: aiohttp in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from datasets) (3.10.5)
# Requirement already satisfied: huggingface-hub>=0.22.0 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from datasets) (0.24.7)
# Requirement already satisfied: packaging in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from aiohttp->datasets) (1.11.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from huggingface-hub>=0.22.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from requests>=2.32.2->datasets) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from pandas->datasets) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install --upgrade datasets
# Out:
# Requirement already satisfied: datasets in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (3.0.0)
# Requirement already satisfied: filelock in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from datasets) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from datasets) (4.66.5)
# Requirement already satisfied: xxhash in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.2.0)
# Requirement already satisfied: aiohttp in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from datasets) (3.10.5)
# Requirement already satisfied: huggingface-hub>=0.22.0 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from datasets) (0.24.7)
# Requirement already satisfied: packaging in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from aiohttp->datasets) (1.11.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from huggingface-hub>=0.22.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from requests>=2.32.2->datasets) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from pandas->datasets) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\kienb\anaconda3\envs\kien\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
import json
import os
import datasets 
from datasets import DatasetBuilder, SplitGenerator
# Find for instance the citation on arxiv or on the dataset repo/website
_CITATION = """\
@article{seker2022generalized, title={A generalized framework for recognition of expiration dates on product packages using fully convolutional networks}, author={Seker, Ahmet Cagatay and Ahn, Sang Chul}, journal={Expert Systems with Applications}, pages={117310}, year={2022}, publisher={Elsevier} }
"""

_DESCRIPTION = """\
The dataset for Date detection in the proposed framework aims to provide annotated images that are relevant for training and evaluating models tasked with detecting dates within product labels or similar contexts.
"""

_HOMEPAGE = "https://acseker.github.io/ExpDateWebsite/"

_LICENSE = "https://licenses.nuget.org/AFL-3.0"

_URLs = {
    "products_synth": "https://huggingface.co/datasets/dimun/ExpirationDate/resolve/main/Products-Synth.zip?download=true",
    "products_real": "https://huggingface.co/datasets/dimun/ExpirationDate/resolve/main/Products-Real.zip?download=true",
}


def has_extension(file_path, extensions):
    _, file_extension = os.path.splitext(file_path)
    return file_extension.lower() in extensions


logger = datasets.logging.get_logger(__name__)


class ExpirationDate(datasets.GeneratorBasedBuilder):
    VERSION = datasets.Version("0.0.1")
    CATEGORIES = ["prod", "date", "due", "code"]
    
    def __init__(self):
        pass
    def _info(self):
        features = datasets.Features(
            {
                "id": datasets.Value("string"),
                "transcriptions": datasets.Sequence(datasets.Value("string")),
                "bboxes_block": datasets.Sequence(datasets.Sequence(datasets.Value("int64"))),
                "categories": datasets.Sequence(datasets.features.ClassLabel(names=self.CATEGORIES)),
                "image_path": datasets.Value("string"),
                "width": datasets.Value("int32"),
                "height": datasets.Value("int32")
            }
        )

        return datasets.DatasetInfo(
            # Đây là mô tả sẽ xuất hiện trên trang bộ dữ liệu.
            description=_DESCRIPTION,
            # Các tính năng/mục tiêu của tập dữ liệu
            features=features,
            # Trang chủ của tập dữ liệu cho tài liệu
            homepage=_HOMEPAGE,
            # Giấy phép cho tập dữ liệu nếu có
            license=_LICENSE,
            # Trích dẫn cho tập dữ liệu
            citation=_CITATION,
        )

    def _split_generators(self):
        """Returns SplitGenerators."""
        
        # Đường dẫn đến các thư mục đã giải nén
        synth_data_dir = os.path.join(".", "Products-Synth")
        real_data_dir = os.path.join(".", "Products-Real")

        return [
            SplitGenerator(
                name=datasets.Split.TRAIN,
                gen_kwargs={
                    "filepath": synth_data_dir,
                    "split": "train",  # Chỉ định rõ ràng cho huấn luyện
                },
            ),
            SplitGenerator(
                name=datasets.Split.VALIDATION,
                gen_kwargs={
                    "filepath": real_data_dir,
                    "split": "validation",  # Chỉ định rõ ràng cho xác thực
                },
            ),
            SplitGenerator(
                name=datasets.Split.TEST,
                gen_kwargs={
                    "filepath": real_data_dir,
                    "split": "test",  # Chỉ định rõ ràng cho kiểm tra
                },
            ),
        ]

    def _generate_examples(self, filepath, split):
        logger.info(
            f"⏳ Generating examples from = {filepath} to the split {split}")
        ann_file = os.path.join(filepath, split, "annotations.json")

        # lấy json
        with open(ann_file, "r", encoding="utf8") as f:
            features_map = json.load(f)

        img_dir = os.path.join(filepath, split, "images")
        img_listdir = os.listdir(img_dir)

        for guid, filename in enumerate(img_listdir):
            if filename.endswith(".jpg"):
                image_features = features_map[filename]
                image_ann = image_features.get("ann")

                transcriptions = [box.get("transcription", "")
                                  for box in image_ann]
                bboxes_block = [box.get("bbox") for box in image_ann]
                categories = [box.get("cls") if box.get(
                    "cls") in self.CATEGORIES else "date" for box in image_ann]

                # lấy ảnh
                image_path = os.path.join(img_dir, filename)

                yield guid, {
                    "id": filename,
                    "transcriptions": transcriptions,
                    "bboxes_block": bboxes_block,
                    "categories": categories,
                    "image_path": image_path,
                    "width": image_features.get("width"),
                    "height": image_features.get("height"),
                }

# Tạo đối tượng của lớp ExpirationDateDataset
dataset_builder = ExpirationDate()

# Gọi hàm _split_generators
dataset = dataset_builder._split_generators()

# In kết quả
for split in dataset:
    print(f"Split Name: {split.name}, Filepath: {split.gen_kwargs['filepath']}")
# Out:
# Split Name: train, Filepath: .\Products-Synth
# Split Name: validation, Filepath: .\Products-Real
# Split Name: test, Filepath: .\Products-Real

# %%
import easyocr
import cv2
import matplotlib.pyplot as plt

# Khởi tạo EasyOCR
reader = easyocr.Reader(['en'])  # Bạn có thể chỉ định ngôn ngữ khác nếu cần

def detect_text(image_path):
    # Đọc hình ảnh
    img = cv2.imread(image_path)

    # Nhận diện văn bản
    results = reader.readtext(img)

    return results, img
# Thay đổi đường dẫn đến hình ảnh của bạn
image_path = './train/images/img_00006.jpg'
detected_texts, img = detect_text(image_path)

# Vẽ hình chữ nhật quanh văn bản phát hiện
for (bbox, text, prob) in detected_texts:
    (top_left, top_right, bottom_right, bottom_left) = bbox
    top_left = tuple(map(int, top_left))
    bottom_right = tuple(map(int, bottom_right))

    cv2.rectangle(img, top_left, bottom_right, (0, 255, 0), 2)
    cv2.putText(img, text, (top_left[0], top_left[1]-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

# Hiển thị hình ảnh với văn bản được phát hiện
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# c:\Users\kienb\anaconda3\envs\kien\Lib\site-packages\easyocr\detection.py:85: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   net.load_state_dict(copyStateDict(torch.load(trained_model, map_location=device)))
# c:\Users\kienb\anaconda3\envs\kien\Lib\site-packages\easyocr\recognition.py:182: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=device))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 18
#      16 # Thay đổi đường dẫn đến hình ảnh của bạn
#      17 image_path = './train/images/img_00006.jpg'
# ---> 18 detected_texts, img = detect_text(image_path)
#      20 # Vẽ hình chữ nhật quanh văn bản phát hiện
#      21 for (bbox, text, prob) in detected_texts:
#
# Cell In[30], line 13, in detect_text(image_path)
#      10 img = cv2.imread(image_path)
#      12 # Nhận diện văn bản
# ---> 13 results = reader.readtext(img)
#      15 return results, img
#
# File c:\Users\kienb\anaconda3\envs\kien\Lib\site-packages\easyocr\easyocr.py:454, in Reader.readtext(self, image, decoder, beamWidth, batch_size, workers, allowlist, blocklist, detail, rotation_info, paragraph, min_size, contrast_ths, adjust_contrast, filter_ths, text_threshold, low_text, link_threshold, canvas_size, mag_ratio, slope_ths, ycenter_ths, height_ths, width_ths, y_ths, x_ths, add_margin, threshold, bbox_min_score, bbox_min_size, max_candidates, output_format)
#     440 def readtext(self, image, decoder = 'greedy', beamWidth= 5, batch_size = 1,\
#     441              workers = 0, allowlist = None, blocklist = None, detail = 1,\
#     442              rotation_info = None, paragraph = False, min_size = 20,\
#    (...)
#     448              threshold = 0.2, bbox_min_score = 0.2, bbox_min_size = 3, max_candidates = 0,
#     449              output_format='standard'):
#     450     '''
#     451     Parameters:
#     452     image: file path or numpy-array or a byte stream object
#     453     '''
# --> 454     img, img_cv_grey = reformat_input(image)
#     456     horizontal_list, free_list = self.detect(img,
#     457                                              min_size = min_size, text_threshold = text_threshold,\
#     458                                              low_text = low_text, link_threshold = link_threshold,\
#    (...)
#     464                                              bbox_min_size = bbox_min_size, max_candidates = max_candidates
#     465                                              )
#     466     # get the 1st result from hor & free list as self.detect returns a list of depth 3
#
# File c:\Users\kienb\anaconda3\envs\kien\Lib\site-packages\easyocr\utils.py:767, in reformat_input(image)
#     765     img_cv_grey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#     766 else:
# --> 767     raise ValueError('Invalid input type. Supporting format = string(file path or url), bytes, numpy array')
#     769 return img, img_cv_grey
#
# ValueError: Invalid input type. Supporting format = string(file path or url), bytes, numpy array

# %%
# Create an instance of the ExpirationDate dataset builder
dataset_builder = ExpirationDate()

# Call the _split_generators method
dataset_splits = dataset_builder._split_generators()

# Print the split information
for split in dataset_splits:
    print(f"Split Name: {split.name}, Filepath: {split.gen_kwargs['filepath']}")
# Out:
# Split Name: train, Filepath: .\Products-Synth
# Split Name: validation, Filepath: .\Products-Real
# Split Name: test, Filepath: .\Products-Real

# %%
import os
import json
import logging

# Khởi tạo logger
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

def generate_examples(filepath, split):
    # Ghi log thông tin
    logger.info(f"⏳ Generating examples from = {filepath} to the split {split}")

    # Lấy đường dẫn đến tệp JSON
    ann_file = os.path.join(filepath, split, "annotations.json")

    # Lấy đường dẫn tuyệt đối
    absolute_path = os.path.abspath(ann_file)

    # In đường dẫn tuyệt đối
    print(f"Absolute path to annotations.json: {absolute_path}")

    # Kiểm tra xem tệp có tồn tại không
    if not os.path.exists(absolute_path):
        logger.error(f"Error: The file does not exist at {absolute_path}")
        return

    logger.info("Data loaded successfully!")
    
    # Đọc dữ liệu JSON
    with open(absolute_path, 'r', encoding='utf-8') as f:
        features_map = json.load(f)

    # Kiểm tra sự tồn tại của thư mục hình ảnh
    img_dir = os.path.join(filepath, split, "images")
    if not os.path.exists(img_dir):
        logger.error(f"Error: The image directory does not exist at {img_dir}")
        return

    img_listdir = os.listdir(img_dir)

    for guid, filename in enumerate(img_listdir):
        if filename.endswith(".jpg"):
            image_features = features_map.get(filename)
            if image_features is None:
                logger.warning(f"Warning: No features found for {filename}")
                continue  # Bỏ qua nếu không có dữ liệu cho ảnh

            image_ann = image_features.get("ann")

            transcriptions = [box.get("transcription", "") for box in image_ann]
            bboxes_block = [box.get("bbox") for box in image_ann]
            categories = [box.get("cls") if box.get("cls") in self.CATEGORIES else "date" for box in image_ann]

            # Lấy đường dẫn ảnh
            image_path = os.path.join(img_dir, filename)

            yield guid, {
                "id": filename,
                "transcriptions": transcriptions,
                "bboxes_block": bboxes_block,
                "categories": categories,
                "image_path": image_path,
                "width": image_features.get("width"),
                "height": image_features.get("height"),
            }

# Ví dụ gọi hàm
filepath = './ExpirationDate/Products-Real/train'  # Ví dụ
split = 'train'  # Ví dụ

for example in generate_examples(filepath, split):
    print(example)
# Out:
# INFO:__main__:⏳ Generating examples from = ./ExpirationDate/Products-Real/train to the split train
# ERROR:__main__:Error: The file does not exist at c:\Users\kienb\Downloads\Test_ORC\ExpirationDate\ExpirationDate\Products-Real\train\train\annotations.json
# Absolute path to annotations.json: c:\Users\kienb\Downloads\Test_ORC\ExpirationDate\ExpirationDate\Products-Real\train\train\annotations.json

# %%
import os
import json
import easyocr
import cv2

# Khởi tạo EasyOCR
reader = easyocr.Reader(['en'])

def detect_expiration_date(image_path):
    img = cv2.imread(image_path)
    results = reader.readtext(img)
    expiration_dates = []
    
    for (bbox, text, prob) in results:
        if "expiry" in text.lower() or "expiration" in text.lower():
            expiration_dates.append(text)

    return expiration_dates

# Sử dụng đường dẫn tuyệt đối
json_path = os.path.abspath('./ExpirationDate/Products-Real/train/annotations.json')

# Kiểm tra xem tệp có tồn tại không
if not os.path.exists(json_path):
    print(f"Error: The file does not exist at {json_path}")
else:
    # Đọc dữ liệu JSON
    with open(json_path, 'r', encoding='utf-8') as f:
        features_map = json.load(f)

    img_dir = os.path.join(os.path.dirname(json_path), "images")
    for filename, features in features_map.items():
        if features.get("ann"):
            image_path = os.path.join(img_dir, filename)
            
            if not os.path.exists(image_path):
                print(f"Warning: Image file does not exist at {image_path}")
                continue

            expiration_dates = detect_expiration_date(image_path)
            print(f"Detected expiration dates for {filename}: {expiration_dates}")
# Out:
# Error: The file does not exist at c:\Users\kienb\Downloads\Test_ORC\ExpirationDate\ExpirationDate\Products-Real\train\annotations.json

# %%
import os
import json
import logging
import cv2

# Khởi tạo logger
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

def generate_examples(filepath, split):
    logger.info(f"⏳ Generating examples from = {filepath} to the split {split}")

    ann_file = os.path.join(filepath, split, "annotations.json")
    absolute_path = os.path.abspath(ann_file)
    print(f"Absolute path to annotations.json: {absolute_path}")

    if not os.path.exists(absolute_path):
        logger.error(f"Error: The file does not exist at {absolute_path}")
        return

    logger.info("Data loaded successfully!")

    with open(absolute_path, 'r', encoding='utf-8') as f:
        features_map = json.load(f)

    img_dir = os.path.join(filepath, split, "images")
    if not os.path.exists(img_dir):
        logger.error(f"Error: The image directory does not exist at {img_dir}")
        return

    img_listdir = os.listdir(img_dir)

    for guid, filename in enumerate(img_listdir):
        if filename.endswith(".jpg"):
            image_features = features_map.get(filename)
            if image_features is None:
                logger.warning(f"Warning: No features found for {filename}")
                continue

            image_ann = image_features.get("ann")

            transcriptions = [box.get("transcription", "") for box in image_ann]
            bboxes_block = [box.get("bbox") for box in image_ann]
            categories = [box.get("cls") for box in image_ann]

            image_path = os.path.join(img_dir, filename)

            yield guid, {
                "id": filename,
                "transcriptions": transcriptions,
                "bboxes_block": bboxes_block,
                "categories": categories,
                "image_path": image_path,
                "width": image_features.get("width"),
                "height": image_features.get("height"),
            }

def display_images(filepath, split):
    for guid, example in generate_examples(filepath, split):
        image_path = example["image_path"]
        image = cv2.imread(image_path)

        for idx, annotation in enumerate(example['bboxes_block']):
            bbox = annotation
            cv2.rectangle(image, (bbox[0], bbox[1]), (bbox[2], bbox[3]), (0, 255, 0), 2)

            if example['transcriptions'][idx]:
                cv2.putText(image, example['transcriptions'][idx], (bbox[0], bbox[1] - 10), 
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)

        cv2.imshow(example["id"], image)
        cv2.waitKey(0)

    cv2.destroyAllWindows()

# Ví dụ gọi hàm
filepath = './ExpirationDate/Products-Real/train'
split = 'train'

display_images(filepath, split)
# Out:
# INFO:__main__:⏳ Generating examples from = ./ExpirationDate/Products-Real/train to the split train
# ERROR:__main__:Error: The file does not exist at c:\Users\kienb\Downloads\Test_ORC\ExpirationDate\ExpirationDate\Products-Real\train\train\annotations.json
# Absolute path to annotations.json: c:\Users\kienb\Downloads\Test_ORC\ExpirationDate\ExpirationDate\Products-Real\train\train\annotations.json
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[42], line 80
#      77 filepath = './ExpirationDate/Products-Real/train'
#      78 split = 'train'
# ---> 80 display_images(filepath, split)
#
# Cell In[42], line 74, in display_images(filepath, split)
#      71     cv2.imshow(example["id"], image)
#      72     cv2.waitKey(0)
# ---> 74 cv2.destroyAllWindows()
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1295: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvDestroyAllWindows'

# %%
import matplotlib.pyplot as plt

def display_images(filepath, split):
    for guid, example in generate_examples(filepath, split):
        image_path = example["image_path"]
        image = cv2.imread(image_path)

        for idx, annotation in enumerate(example['bboxes_block']):
            bbox = annotation
            cv2.rectangle(image, (bbox[0], bbox[1]), (bbox[2], bbox[3]), (0, 255, 0), 2)

            if example['transcriptions'][idx]:
                cv2.putText(image, example['transcriptions'][idx], (bbox[0], bbox[1] - 10), 
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)

        plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        plt.title(example["id"])
        plt.axis('off')
        plt.show()

# Ví dụ gọi hàm
filepath = './ExpirationDate/Products-Real/train'
split = 'train'

display_images(filepath, split)
# Out:
# INFO:__main__:⏳ Generating examples from = ./ExpirationDate/Products-Real/train to the split train
# ERROR:__main__:Error: The file does not exist at c:\Users\kienb\Downloads\Test_ORC\ExpirationDate\ExpirationDate\Products-Real\train\train\annotations.json
# Absolute path to annotations.json: c:\Users\kienb\Downloads\Test_ORC\ExpirationDate\ExpirationDate\Products-Real\train\train\annotations.json

# %%
print(f"Checking for JSON file at: {json_path}")
# Out:
# Checking for JSON file at: ./ExpirationDate/Products-Real/train/annotations.json

# %%
import os

# Lấy đường dẫn tuyệt đối
json_path = os.path.abspath('./ExpirationDate/Products-Real/train/annotations.json')
print(json_path)
# Out:
# c:\Users\kienb\Downloads\Test_ORC\ExpirationDate\ExpirationDate\Products-Real\train\annotations.json

# %%
import os
import cv2
import json
import logging
import matplotlib.pyplot as plt

# Khởi tạo logger
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

def generate_examples(filepath, split):
    logger.info(f"⏳ Generating examples from = {filepath} to the split {split}")

    ann_file = os.path.join(filepath, split, "annotations.json")
    absolute_path = os.path.abspath(ann_file)
    print(f"Absolute path to annotations.json: {absolute_path}")

    if not os.path.exists(absolute_path):
        logger.error(f"Error: The file does not exist at {absolute_path}")
        return

    logger.info("Data loaded successfully!")

    with open(absolute_path, 'r', encoding='utf-8') as f:
        features_map = json.load(f)

    img_dir = os.path.join(filepath, split, "images")
    if not os.path.exists(img_dir):
        logger.error(f"Error: The image directory does not exist at {img_dir}")
        return

    img_listdir = os.listdir(img_dir)

    for guid, filename in enumerate(img_listdir):
        if filename.endswith(".jpg"):
            image_features = features_map.get(filename)
            if image_features is None:
                logger.warning(f"Warning: No features found for {filename}")
                continue

            image_ann = image_features.get("ann")

            transcriptions = [box.get("transcription", "") for box in image_ann]
            bboxes_block = [box.get("bbox") for box in image_ann]
            categories = [box.get("cls") for box in image_ann]

            image_path = os.path.join(img_dir, filename)

            yield guid, {
                "id": filename,
                "transcriptions": transcriptions,
                "bboxes_block": bboxes_block,
                "categories": categories,
                "image_path": image_path,
                "width": image_features.get("width"),
                "height": image_features.get("height"),
            }

def display_single_image(filepath, split, image_id):
    for guid, example in generate_examples(filepath, split):
        print(f"Checking image: {example['id']}")  # In ra tên ảnh đang kiểm tra
        if example["id"] == image_id:
            image_path = example["image_path"]
            image = cv2.imread(image_path)

            for idx, annotation in enumerate(example['bboxes_block']):
                bbox = annotation
                cv2.rectangle(image, (bbox[0], bbox[1]), (bbox[2], bbox[3]), (0, 255, 0), 2)

                if example['transcriptions'][idx]:
                    cv2.putText(image, example['transcriptions'][idx], (bbox[0], bbox[1] - 10), 
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)

            plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
            plt.title(example["id"])
            plt.axis('off')
            plt.show()
            return

    print(f"Image with ID {image_id} not found.")

# Ví dụ gọi hàm để hiển thị một ảnh cụ thể
filepath = './ExpirationDate/Products-Real/train'
split = 'train'
image_id = 'img_00002.jpg'  # Thay đổi ID ảnh theo nhu cầu

display_single_image(filepath, split, image_id)
# Out:
# INFO:__main__:⏳ Generating examples from = ./ExpirationDate/Products-Real/train to the split train
# ERROR:__main__:Error: The file does not exist at c:\Users\kienb\Downloads\Test_ORC\ExpirationDate\ExpirationDate\Products-Real\train\train\annotations.json
# Absolute path to annotations.json: c:\Users\kienb\Downloads\Test_ORC\ExpirationDate\ExpirationDate\Products-Real\train\train\annotations.json
# Image with ID img_00002.jpg not found.

# %%
import os

# Khởi tạo các biến
base_filepath = os.path.abspath('./ExpirationDate/Products-Real')
split = 'train'
ann_file = os.path.join(base_filepath, split, "annotations.json")
img_dir = os.path.join(base_filepath, split, "images")

print("Annotation file path:", ann_file)
print("Image directory path:", img_dir)

# Đọc tệp JSON
if os.path.exists(ann_file):
    with open(ann_file, 'r', encoding='utf-8') as f:
        features_map = json.load(f)
else:
    print("Annotation file does not exist:", ann_file)

# In danh sách ảnh từ JSON
json_images = features_map.keys() if 'features_map' in locals() else []
print("Images in annotations.json:", json_images)

# In danh sách ảnh từ thư mục
img_listdir = os.listdir(img_dir) if os.path.exists(img_dir) else []
print("Images in directory:", img_listdir)
# Out:
# Annotation file path: c:\Users\kienb\Downloads\Test_ORC\ExpirationDate\ExpirationDate\Products-Real\train\annotations.json
# Image directory path: c:\Users\kienb\Downloads\Test_ORC\ExpirationDate\ExpirationDate\Products-Real\train\images
# Annotation file does not exist: c:\Users\kienb\Downloads\Test_ORC\ExpirationDate\ExpirationDate\Products-Real\train\annotations.json
# Images in annotations.json: []
# Images in directory: []

# %%
# Tìm các ảnh có trong JSON nhưng không có trong thư mục
missing_in_directory = [img for img in json_images if img not in img_listdir]
print("Images in annotations.json but missing in directory:", missing_in_directory)

# Tìm các ảnh có trong thư mục nhưng không có trong JSON
missing_in_json = [img for img in img_listdir if img not in json_images]
print("Images in directory but missing in annotations.json:", missing_in_json)
# Out:
# Images in annotations.json but missing in directory: []
# Images in directory but missing in annotations.json: []

# %%
import json
import os

# Đường dẫn đến tệp JSON
json_file_path = '../ExpirationDate/Products-Real/train/annotations.json'  # Thay đổi đường dẫn cho phù hợp

# Đọc tệp JSON
if os.path.exists(json_file_path):
    with open(json_file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    # Truy cập dữ liệu
    for image_id, image_info in data.items():
        print(f"Image ID: {image_id}")
        print(f"Height: {image_info['height']}")
        print(f"Width: {image_info['width']}")

        for annotation in image_info['ann']:
            print(f"  Class: {annotation['cls']}")
            print(f"  Bounding Box: {annotation['bbox']}")
            if 'transcription' in annotation:
                print(f"  Transcription: {annotation['transcription']}")
else:
    print(f"File does not exist: {json_file_path}")
# Out:
# Image ID: img_00001.jpg
# Height: 1008
# Width: 756
#   Class: date
#   Bounding Box: [289, 660, 418, 673]
#   Transcription: 2025/01/28
#   Class: due
#   Bounding Box: [286, 611, 315, 626]
#   Class: due
#   Bounding Box: [353, 642, 429, 657]
# Image ID: img_00002.jpg
# Height: 1107
# Width: 779
#   Class: date
#   Bounding Box: [321, 661, 526, 675]
#   Transcription: 2021/10/28
#   Class: code
#   Bounding Box: [378, 694, 469, 707]
# Image ID: img_00003.jpg
# Height: 1263
# Width: 947
#   Class: date
#   Bounding Box: [285, 767, 519, 784]
#   Transcription: 21.05.26
#   Class: date
#   Bounding Box: [284, 747, 523, 765]
#   Transcription: 20.08.27
#   Class: due
#   Bounding Box: [607, 772, 654, 796]
#   Class: prod
#   Bounding Box: [612, 733, 660, 757]
#   Class: code
#   Bounding Box: [527, 767, 550, 785]
# Image ID: img_00004.jpg
# Height: 839
# Width: 1119
#   Class: date
#   Bounding Box: [551, 393, 758, 409]
#   Transcription: 2021.03.23
#   Class: due
#   Bounding Box: [516, 354, 571, 381]
#   Class: due
#   Bounding Box: [774, 349, 802, 375]
#   Class: code
#   Bounding Box: [643, 371, 740, 388]
# Image ID: img_00005.jpg
# Height: 603
# Width: 796
#   Class: due
#   Bounding Box: [538, 210, 581, 223]
#   Class: due
#   Bounding Box: [503, 266, 567, 279]
#   Class: date
#   Bounding Box: [450, 279, 553, 291]
#   Transcription: 23.07.2022
# Image ID: img_00006.jpg
# Height: 770
# Width: 1027
#   Class: date
#   Bounding Box: [440, 395, 588, 408]
#   Transcription: 22.10.2020
#   Class: date
#   Bounding Box: [441, 409, 582, 421]
#   Transcription: 22.10.2021
#   Class: due
#   Bounding Box: [378, 407, 423, 421]
#   Class: prod
#   Bounding Box: [363, 394, 423, 408]
#   Class: due
#   Bounding Box: [462, 319, 497, 333]
# Image ID: img_00007.jpg
# Height: 1145
# Width: 859
#   Class: date
#   Bounding Box: [296, 759, 403, 775]
#   Transcription: 04/03/2023
#   Class: due
#   Bounding Box: [200, 758, 289, 774]
# Image ID: img_00008.jpg
# Height: 761
# Width: 1014
#   Class: date
#   Bounding Box: [208, 255, 340, 272]
#   Transcription: 29 NOV 2021
#   Class: due
#   Bounding Box: [264, 219, 282, 232]
#   Class: code
#   Bounding Box: [394, 256, 453, 273]
# Image ID: img_00009.jpg
# Height: 1006
# Width: 1342
#   Class: date
#   Bounding Box: [559, 631, 829, 650]
#   Transcription: 25.09.2021
# Image ID: img_00010.jpg
# Height: 1049
# Width: 876
#   Class: date
#   Bounding Box: [516, 688, 677, 703]
#   Transcription: 25 07 2020
#   Class: date
#   Bounding Box: [515, 704, 674, 718]
#   Transcription: 23 10 2021
#   Class: prod
#   Bounding Box: [327, 689, 375, 704]
#   Class: due
#   Bounding Box: [327, 704, 374, 718]
# Image ID: img_00011.jpg
# Height: 756
# Width: 1008
#   Class: date
#   Bounding Box: [487, 357, 604, 374]
#   Transcription: 15-09-2021
#   Class: code
#   Bounding Box: [558, 375, 600, 390]
# Image ID: img_00012.jpg
# Height: 756
# Width: 1008
#   Class: date
#   Bounding Box: [417, 275, 522, 292]
#   Transcription: 15.10.2021
#   Class: code
#   Bounding Box: [493, 294, 544, 311]
#   Class: due
#   Bounding Box: [346, 210, 384, 229]
# Image ID: img_00013.jpg
# Height: 756
# Width: 1008
#   Class: date
#   Bounding Box: [409, 526, 508, 544]
#   Transcription: FEB/26/21
#   Class: code
#   Bounding Box: [531, 524, 585, 542]
#   Class: due
#   Bounding Box: [374, 528, 400, 549]
# Image ID: img_00014.jpg
# Height: 816
# Width: 1234
#   Class: date
#   Bounding Box: [285, 580, 435, 599]
#   Transcription: MAR 22 21
#   Class: code
#   Bounding Box: [453, 582, 537, 599]
#   Class: due
#   Bounding Box: [291, 553, 372, 571]
# Image ID: img_00015.jpg
# Height: 937
# Width: 1248
#   Class: date
#   Bounding Box: [700, 381, 871, 401]
#   Transcription: 2021.07.01
#   Class: code
#   Bounding Box: [791, 358, 872, 378]
#   Class: due
#   Bounding Box: [882, 409, 920, 434]
# Image ID: img_00016.jpg
# Height: 684
# Width: 913
#   Class: date
#   Bounding Box: [306, 455, 393, 470]
#   Transcription: 03/04/23
#   Class: due
#   Bounding Box: [227, 455, 296, 472]
# Image ID: img_00017.jpg
# Height: 776
# Width: 1035
#   Class: date
#   Bounding Box: [574, 477, 675, 495]
#   Transcription: 15/07/2020
#   Class: date
#   Bounding Box: [573, 497, 670, 514]
#   Transcription: 11/05/2021
#   Class: due
#   Bounding Box: [558, 456, 596, 470]
#   Class: due
#   Bounding Box: [465, 497, 498, 514]
#   Class: prod
#   Bounding Box: [466, 477, 510, 495]
# Image ID: img_00018.jpg
# Height: 822
# Width: 1096
#   Class: date
#   Bounding Box: [488, 416, 676, 435]
#   Transcription: 2021.06.08
#   Class: due
#   Bounding Box: [682, 417, 750, 436]
#   Class: due
#   Bounding Box: [379, 432, 455, 458]
#   Class: code
#   Bounding Box: [587, 441, 673, 460]
# Image ID: img_00019.jpg
# Height: 793
# Width: 1075
#   Class: date
#   Bounding Box: [387, 496, 579, 513]
#   Transcription: 2021.01.04
#   Class: date
#   Bounding Box: [397, 514, 588, 531]
#   Transcription: 2021.07.03
#   Class: due
#   Bounding Box: [629, 510, 669, 532]
#   Class: due
#   Bounding Box: [266, 511, 346, 534]
# Image ID: img_00020.jpg
# Height: 808
# Width: 1094
#   Class: date
#   Bounding Box: [479, 322, 688, 339]
#   Transcription: 2021.07.09
#   Class: due
#   Bounding Box: [686, 351, 712, 368]
#   Class: due
#   Bounding Box: [479, 276, 535, 294]
#   Class: code
#   Bounding Box: [478, 339, 582, 356]
# Image ID: img_00021.jpg
# Height: 802
# Width: 1069
#   Class: date
#   Bounding Box: [649, 314, 881, 331]
#   Transcription: 2021 12 04
#   Class: due
#   Bounding Box: [500, 315, 625, 331]
# Image ID: img_00022.jpg
# Height: 708
# Width: 975
#   Class: date
#   Bounding Box: [441, 314, 642, 331]
#   Transcription: MAY 27 2021
#   Class: due
#   Bounding Box: [384, 314, 421, 330]
# Image ID: img_00023.jpg
# Height: 935
# Width: 1246
#   Class: due
#   Bounding Box: [638, 370, 666, 394]
#   Class: code
#   Bounding Box: [588, 324, 650, 343]
#   Class: code
#   Bounding Box: [523, 324, 537, 343]
#   Class: date
#   Bounding Box: [523, 346, 651, 366]
#   Transcription: 2021.04.05
# Image ID: img_00024.jpg
# Height: 990
# Width: 1320
#   Class: date
#   Bounding Box: [887, 372, 1006, 393]
#   Transcription: 19 09 2021
#   Class: date
#   Bounding Box: [879, 339, 1000, 362]
#   Transcription: 19 09 2020
#   Class: prod
#   Bounding Box: [780, 338, 853, 361]
#   Class: code
#   Bounding Box: [948, 492, 1003, 510]
# Image ID: img_00025.jpg
# Height: 1011
# Width: 1348
#   Class: date
#   Bounding Box: [261, 591, 418, 612]
#   Transcription: 07 FEB 2022
#   Class: due
#   Bounding Box: [373, 526, 397, 543]
#   Class: code
#   Bounding Box: [490, 588, 562, 610]
# Image ID: img_00026.jpg
# Height: 971
# Width: 1295
#   Class: date
#   Bounding Box: [598, 524, 786, 548]
#   Transcription: 2022.06.20
#   Class: due
#   Bounding Box: [507, 521, 565, 549]
#   Class: due
#   Bounding Box: [817, 520, 849, 546]
# Image ID: img_00027.jpg
# Height: 949
# Width: 1266
#   Class: due
#   Bounding Box: [716, 328, 754, 355]
#   Class: date
#   Bounding Box: [525, 306, 718, 326]
#   Transcription: 2021.06.02
#   Class: code
#   Bounding Box: [621, 284, 716, 303]
# Image ID: img_00028.jpg
# Height: 694
# Width: 948
#   Class: date
#   Bounding Box: [363, 419, 444, 433]
#   Transcription: 2020/02/15
#   Class: date
#   Bounding Box: [363, 511, 444, 525]
#   Transcription: 2023/02/15
# Image ID: img_00029.jpg
# Height: 1049
# Width: 1399
#   Class: date
#   Bounding Box: [897, 686, 1021, 709]
#   Transcription: 01/12/21
# Image ID: img_00030.jpg
# Height: 1466
# Width: 1099
#   Class: date
#   Bounding Box: [377, 967, 562, 987]
#   Transcription: 2025/05/19
#   Class: due
#   Bounding Box: [469, 944, 577, 963]
#   Class: due
#   Bounding Box: [353, 898, 401, 920]
# Image ID: img_00031.jpg
# Height: 1343
# Width: 1007
#   Class: date
#   Bounding Box: [668, 794, 781, 813]
#   Transcription: 2022.09.02
#   Class: due
#   Bounding Box: [557, 793, 600, 813]
# Image ID: img_00032.jpg
# Height: 987
# Width: 1316
#   Class: date
#   Bounding Box: [686, 661, 821, 685]
#   Transcription: 01/11/2021
# Image ID: img_00033.jpg
# Height: 1231
# Width: 924
#   Class: date
#   Bounding Box: [497, 399, 646, 417]
#   Transcription: 31-08-2021
# Image ID: img_00034.jpg
# Height: 1007
# Width: 1343
#   Class: date
#   Bounding Box: [669, 507, 804, 532]
#   Transcription: 01.2022
#   Class: due
#   Bounding Box: [592, 506, 650, 531]
# Image ID: img_00035.jpg
# Height: 1000
# Width: 1333
#   Class: date
#   Bounding Box: [586, 512, 713, 536]
#   Transcription: 01.2022
#   Class: due
#   Bounding Box: [513, 512, 568, 535]
# Image ID: img_00036.jpg
# Height: 895
# Width: 669
#   Class: date
#   Bounding Box: [284, 641, 405, 660]
#   Transcription: 20-09-2021
# Image ID: img_00037.jpg
# Height: 964
# Width: 722
#   Class: date
#   Bounding Box: [247, 765, 408, 784]
#   Transcription: 2022.05.05
#   Class: code
#   Bounding Box: [392, 787, 472, 808]
#   Class: due
#   Bounding Box: [513, 808, 531, 824]
#   Class: due
#   Bounding Box: [132, 732, 164, 748]
# Image ID: img_00038.jpg
# Height: 1008
# Width: 756
#   Class: date
#   Bounding Box: [326, 661, 532, 679]
#   Transcription: 2021.10.19
#   Class: due
#   Bounding Box: [534, 675, 564, 689]
#   Class: due
#   Bounding Box: [326, 616, 398, 634]
# Image ID: img_00039.jpg
# Height: 949
# Width: 711
#   Class: date
#   Bounding Box: [353, 363, 540, 380]
#   Transcription: 2021.07.21
#   Class: code
#   Bounding Box: [380, 382, 452, 398]
#   Class: due
#   Bounding Box: [312, 384, 357, 400]
# Image ID: img_00040.jpg
# Height: 905
# Width: 678
#   Class: date
#   Bounding Box: [252, 768, 402, 786]
#   Transcription: 2022.06.06
#   Class: code
#   Bounding Box: [418, 767, 429, 786]
# Image ID: img_00041.jpg
# Height: 902
# Width: 678
#   Class: date
#   Bounding Box: [275, 658, 406, 673]
#   Transcription: 2021.09.17
#   Class: due
#   Bounding Box: [217, 643, 257, 659]
# Image ID: img_00042.jpg
# Height: 872
# Width: 651
#   Class: date
#   Bounding Box: [121, 674, 262, 691]
#   Transcription: 2021.12.08
#   Class: code
#   Bounding Box: [121, 693, 191, 709]
#   Class: due
#   Bounding Box: [92, 639, 165, 660]
#   Class: due
#   Bounding Box: [322, 713, 355, 731]
# Image ID: img_00043.jpg
# Height: 973
# Width: 729
#   Class: date
#   Bounding Box: [398, 372, 513, 391]
#   Transcription: 2021.12.18
#   Class: due
#   Bounding Box: [439, 396, 475, 415]
#   Class: code
#   Bounding Box: [479, 396, 504, 414]
# Image ID: img_00044.jpg
# Height: 962
# Width: 711
#   Class: date
#   Bounding Box: [260, 749, 381, 768]
#   Transcription: 2022.03.11
# Image ID: img_00045.jpg
# Height: 888
# Width: 664
#   Class: due
#   Bounding Box: [208, 606, 249, 623]
#   Class: date
#   Bounding Box: [264, 607, 405, 624]
#   Transcription: 2022/02/26
# Image ID: img_00046.jpg
# Height: 876
# Width: 654
#   Class: date
#   Bounding Box: [218, 241, 294, 257]
#   Transcription: 02.01
#   Class: code
#   Bounding Box: [323, 238, 392, 257]
#   Class: due
#   Bounding Box: [416, 273, 444, 288]
#   Class: due
#   Bounding Box: [186, 273, 243, 289]
# Image ID: img_00047.jpg
# Height: 1008
# Width: 756
#   Class: date
#   Bounding Box: [218, 312, 296, 329]
#   Transcription: 02.02
#   Class: code
#   Bounding Box: [329, 313, 412, 333]
#   Class: due
#   Bounding Box: [180, 348, 241, 366]
#   Class: due
#   Bounding Box: [427, 351, 458, 367]
# Image ID: img_00048.jpg
# Height: 873
# Width: 654
#   Class: date
#   Bounding Box: [251, 488, 344, 504]
#   Transcription: 2021.06.10
#   Class: code
#   Bounding Box: [350, 486, 364, 503]
# Image ID: img_00049.jpg
# Height: 1008
# Width: 756
#   Class: date
#   Bounding Box: [279, 643, 448, 662]
#   Transcription: 2021.08.23
#   Class: code
#   Bounding Box: [332, 663, 414, 682]
#   Class: due
#   Bounding Box: [441, 670, 472, 693]
# Image ID: img_00050.jpg
# Height: 939
# Width: 702
#   Class: date
#   Bounding Box: [220, 728, 331, 746]
#   Transcription: 13/03/22
#   Class: code
#   Bounding Box: [334, 748, 397, 766]
#   Class: code
#   Bounding Box: [345, 727, 358, 745]
# Image ID: img_00051.jpg
# Height: 902
# Width: 756
#   Class: date
#   Bounding Box: [271, 687, 364, 704]
#   Transcription: 2021.10.30
#   Class: due
#   Bounding Box: [228, 688, 259, 704]
# Image ID: img_00052.jpg
# Height: 1008
# Width: 756
#   Class: date
#   Bounding Box: [244, 494, 411, 512]
#   Transcription: 2021.07.29
#   Class: due
#   Bounding Box: [415, 493, 459, 509]
# Image ID: img_00053.jpg
# Height: 879
# Width: 659
#   Class: date
#   Bounding Box: [300, 417, 446, 433]
#   Transcription: 2021.05.26
#   Class: code
#   Bounding Box: [404, 434, 431, 453]
#   Class: code
#   Bounding Box: [317, 434, 389, 452]
# Image ID: img_00054.jpg
# Height: 1059
# Width: 794
#   Class: date
#   Bounding Box: [214, 657, 345, 676]
#   Transcription: 21.01.25
#   Class: date
#   Bounding Box: [212, 680, 343, 699]
#   Transcription: 21.02.10
#   Class: due
#   Bounding Box: [346, 678, 383, 698]
#   Class: prod
#   Bounding Box: [347, 657, 384, 675]
# Image ID: img_00055.jpg
# Height: 1051
# Width: 788
#   Class: date
#   Bounding Box: [297, 400, 435, 419]
#   Transcription: 2021.01.20
#   Class: date
#   Bounding Box: [297, 421, 435, 440]
#   Transcription: 2021.10.19
# Image ID: img_00056.jpg
# Height: 1025
# Width: 769
#   Class: date
#   Bounding Box: [258, 661, 387, 679]
#   Transcription: 2022.06.11
#   Class: code
#   Bounding Box: [402, 661, 464, 679]
# Image ID: img_00057.jpg
# Height: 1061
# Width: 797
#   Class: date
#   Bounding Box: [205, 632, 323, 652]
#   Transcription: 17.07.2022
# Image ID: img_00058.jpg
# Height: 1063
# Width: 748
#   Class: date
#   Bounding Box: [247, 594, 446, 612]
#   Transcription: 2021/10/28
#   Class: code
#   Bounding Box: [303, 630, 392, 644]
# Image ID: img_00059.jpg
# Height: 929
# Width: 693
#   Class: date
#   Bounding Box: [284, 482, 468, 497]
#   Transcription: 2021/10/28
#   Class: code
#   Bounding Box: [335, 515, 417, 528]
# Image ID: img_00060.jpg
# Height: 1112
# Width: 834
#   Class: date
#   Bounding Box: [430, 409, 534, 428]
#   Transcription: 2021 07 02
#   Class: due
#   Bounding Box: [486, 377, 515, 395]
# Image ID: img_00061.jpg
# Height: 1058
# Width: 794
#   Class: date
#   Bounding Box: [322, 321, 425, 339]
#   Transcription: 29 08 2020
#   Class: date
#   Bounding Box: [323, 345, 423, 364]
#   Transcription: 29 05 2021
#   Class: due
#   Bounding Box: [269, 343, 308, 362]
#   Class: prod
#   Bounding Box: [251, 319, 306, 341]
#   Class: code
#   Bounding Box: [437, 322, 448, 340]
#   Class: code
#   Bounding Box: [373, 471, 419, 488]
#   Class: code
#   Bounding Box: [253, 467, 270, 488]
# Image ID: img_00062.jpg
# Height: 1090
# Width: 818
#   Class: date
#   Bounding Box: [251, 724, 419, 745]
#   Transcription: 03/04/2020
#   Class: date
#   Bounding Box: [233, 747, 391, 764]
#   Transcription: 03/07/2021
#   Class: due
#   Bounding Box: [171, 746, 217, 766]
#   Class: prod
#   Bounding Box: [170, 726, 233, 745]
#   Class: code
#   Bounding Box: [320, 766, 381, 784]
# Image ID: img_00063.jpg
# Height: 1040
# Width: 780
#   Class: date
#   Bounding Box: [292, 659, 490, 676]
#   Transcription: 2021 09 14
#   Class: due
#   Bounding Box: [209, 657, 266, 675]
#   Class: due
#   Bounding Box: [69, 564, 119, 577]
# Image ID: img_00064.jpg
# Height: 962
# Width: 722
#   Class: date
#   Bounding Box: [390, 304, 515, 323]
#   Transcription: 2021.09.30
#   Class: code
#   Bounding Box: [483, 325, 538, 345]
# Image ID: img_00065.jpg
# Height: 1246
# Width: 934
#   Class: date
#   Bounding Box: [495, 822, 603, 841]
#   Transcription: 24/07/2020
#   Class: date
#   Bounding Box: [503, 848, 606, 865]
#   Transcription: 24/10/2021
#   Class: due
#   Bounding Box: [383, 844, 442, 863]
# Image ID: img_00066.jpg
# Height: 1008
# Width: 756
#   Class: date
#   Bounding Box: [153, 367, 363, 384]
#   Transcription: 2022.09.16
#   Class: code
#   Bounding Box: [386, 365, 479, 383]
#   Class: code
#   Bounding Box: [548, 365, 565, 383]
# Image ID: img_00067.jpg
# Height: 1008
# Width: 756
#   Class: date
#   Bounding Box: [375, 471, 493, 491]
#   Transcription: 2021.04.05
#   Class: code
#   Bounding Box: [432, 442, 493, 467]
#   Class: due
#   Bounding Box: [480, 496, 505, 519]
#   Class: code
#   Bounding Box: [373, 442, 387, 466]
# Image ID: img_00068.jpg
# Height: 1008
# Width: 756
#   Class: date
#   Bounding Box: [294, 758, 432, 778]
#   Transcription: 2021.10.20
#   Class: due
#   Bounding Box: [196, 764, 239, 779]
# Image ID: img_00069.jpg
# Height: 1271
# Width: 953
#   Class: date
#   Bounding Box: [284, 935, 431, 960]
#   Transcription: 21.02.05
#   Class: date
#   Bounding Box: [286, 906, 432, 932]
#   Transcription: 21.01.07
#   Class: due
#   Bounding Box: [468, 910, 493, 931]
#   Class: prod
#   Bounding Box: [468, 880, 493, 903]
#   Class: code
#   Bounding Box: [438, 921, 457, 944]
# Image ID: img_00070.jpg
# Height: 1184
# Width: 888
#   Class: date
#   Bounding Box: [460, 835, 583, 856]
#   Transcription: 2024.03.10
#   Class: due
#   Bounding Box: [445, 808, 498, 823]
# Image ID: img_00071.jpg
# Height: 1129
# Width: 847
#   Class: date
#   Bounding Box: [337, 644, 418, 666]
#   Transcription: 11 12 21
#   Class: due
#   Bounding Box: [283, 644, 323, 668]
#   Class: code
#   Bounding Box: [282, 672, 333, 692]
#   Class: code
#   Bounding Box: [411, 674, 424, 692]
# Image ID: img_00072.jpg
# Height: 1106
# Width: 829
#   Class: date
#   Bounding Box: [270, 526, 368, 548]
#   Transcription: 22.01.25
#   Class: due
#   Bounding Box: [494, 535, 530, 559]
#   Class: code
#   Bounding Box: [378, 525, 436, 546]
# Image ID: img_00073.jpg
# Height: 1065
# Width: 799
#   Class: date
#   Bounding Box: [170, 294, 247, 314]
#   Transcription: 02.14
#   Class: due
#   Bounding Box: [131, 335, 197, 353]
#   Class: due
#   Bounding Box: [394, 338, 424, 354]
#   Class: code
#   Bounding Box: [287, 297, 366, 317]
# Image ID: img_00074.jpg
# Height: 1127
# Width: 846
#   Class: date
#   Bounding Box: [259, 732, 390, 753]
#   Transcription: 21.01.29
#   Class: date
#   Bounding Box: [258, 754, 389, 776]
#   Transcription: 21.02.22
#   Class: prod
#   Bounding Box: [393, 729, 427, 750]
#   Class: due
#   Bounding Box: [392, 752, 427, 772]
# Image ID: img_00075.jpg
# Height: 1189
# Width: 892
#   Class: date
#   Bounding Box: [318, 870, 474, 893]
#   Transcription: 2022.07.19
# Image ID: img_00076.jpg
# Height: 1260
# Width: 945
#   Class: date
#   Bounding Box: [357, 573, 508, 597]
#   Transcription: 2022.01.26
#   Class: due
#   Bounding Box: [248, 545, 323, 570]
#   Class: due
#   Bounding Box: [557, 646, 587, 667]
# Image ID: img_00077.jpg
# Height: 1264
# Width: 948
#   Class: date
#   Bounding Box: [366, 351, 503, 376]
#   Transcription: 2023/10/21
#   Class: code
#   Bounding Box: [367, 388, 462, 413]
# Image ID: img_00078.jpg
# Height: 1084
# Width: 813
#   Class: date
#   Bounding Box: [215, 343, 352, 364]
#   Transcription: 2023/11/14
#   Class: code
#   Bounding Box: [217, 384, 306, 405]
# Image ID: img_00079.jpg
# Height: 1313
# Width: 985
#   Class: date
#   Bounding Box: [215, 856, 392, 877]
#   Transcription: 23.07.2021
#   Class: date
#   Bounding Box: [215, 878, 393, 899]
#   Transcription: 24.07.2020
#   Class: due
#   Bounding Box: [165, 767, 220, 786]
#   Class: prod
#   Bounding Box: [119, 1001, 158, 1019]
# Image ID: img_00080.jpg
# Height: 1327
# Width: 995
#   Class: date
#   Bounding Box: [226, 343, 343, 367]
#   Transcription: 02.09
#   Class: due
#   Bounding Box: [215, 404, 304, 431]
#   Class: due
#   Bounding Box: [565, 395, 610, 419]
#   Class: code
#   Bounding Box: [395, 345, 480, 371]
# Image ID: img_00081.jpg
# Height: 1385
# Width: 1039
#   Class: date
#   Bounding Box: [269, 468, 437, 492]
#   Transcription: 10/08/2021
#   Class: code
#   Bounding Box: [280, 498, 290, 524]
# Image ID: img_00082.jpg
# Height: 1347
# Width: 1010
#   Class: date
#   Bounding Box: [391, 941, 584, 967]
#   Transcription: 2022.10.17
#   Class: due
#   Bounding Box: [267, 943, 353, 971]
#   Class: due
#   Bounding Box: [572, 973, 609, 1000]
# Image ID: img_00083.jpg
# Height: 1358
# Width: 1019
#   Class: date
#   Bounding Box: [435, 881, 592, 907]
#   Transcription: 2022/06/30
#   Class: code
#   Bounding Box: [431, 923, 450, 950]
#   Class: code
#   Bounding Box: [432, 963, 484, 983]
# Image ID: img_00084.jpg
# Height: 1228
# Width: 921
#   Class: date
#   Bounding Box: [125, 721, 347, 741]
#   Transcription: 2022.01.18
#   Class: due
#   Bounding Box: [399, 733, 432, 753]
#   Class: code
#   Bounding Box: [349, 723, 370, 741]
# Image ID: img_00085.jpg
# Height: 1255
# Width: 941
#   Class: date
#   Bounding Box: [179, 681, 405, 705]
#   Transcription: 2021.11.11
#   Class: due
#   Bounding Box: [473, 690, 511, 712]
#   Class: code
#   Bounding Box: [409, 681, 431, 702]
# Image ID: img_00086.jpg
# Height: 1211
# Width: 909
#   Class: date
#   Bounding Box: [265, 626, 446, 647]
#   Transcription: 2021.06.25
# Image ID: img_00087.jpg
# Height: 1333
# Width: 1000
#   Class: date
#   Bounding Box: [398, 619, 572, 641]
#   Transcription: 02/12/22
#   Class: due
#   Bounding Box: [514, 599, 560, 621]
# Image ID: img_00088.jpg
# Height: 1402
# Width: 1052
#   Class: date
#   Bounding Box: [456, 498, 561, 526]
#   Transcription: 05.05.2020
#   Class: date
#   Bounding Box: [445, 528, 550, 551]
#   Transcription: 05.05.2022
#   Class: due
#   Bounding Box: [361, 521, 388, 546]
#   Class: prod
#   Bounding Box: [361, 495, 399, 523]
# Image ID: img_00089.jpg
# Height: 1306
# Width: 979
#   Class: date
#   Bounding Box: [230, 798, 393, 824]
#   Transcription: 2023/08/03
#   Class: code
#   Bounding Box: [228, 845, 336, 872]
# Image ID: img_00090.jpg
# Height: 1299
# Width: 974
#   Class: date
#   Bounding Box: [552, 371, 704, 395]
#   Transcription: 03 11 2020
#   Class: date
#   Bounding Box: [550, 398, 702, 419]
#   Transcription: 03 11 2021
# Image ID: img_00091.jpg
# Height: 1390
# Width: 1042
#   Class: date
#   Bounding Box: [398, 640, 597, 664]
#   Transcription: 2020.12.15
#   Class: date
#   Bounding Box: [398, 670, 598, 695]
#   Transcription: 2021.06.14
#   Class: due
#   Bounding Box: [739, 682, 774, 712]
#   Class: prod
#   Bounding Box: [735, 635, 769, 665]
#   Class: code
#   Bounding Box: [614, 639, 715, 663]
#   Class: code
#   Bounding Box: [615, 667, 635, 692]
# Image ID: img_00092.jpg
# Height: 1084
# Width: 813
#   Class: date
#   Bounding Box: [228, 414, 356, 436]
#   Transcription: 2021 08 08
# Image ID: img_00093.jpg
# Height: 1346
# Width: 1009
#   Class: date
#   Bounding Box: [463, 411, 568, 434]
#   Transcription: 15 FEB 22
#   Class: due
#   Bounding Box: [411, 409, 443, 434]
#   Class: code
#   Bounding Box: [569, 412, 584, 433]
#   Class: code
#   Bounding Box: [600, 413, 676, 434]
# Image ID: img_00094.jpg
# Height: 1393
# Width: 1045
#   Class: date
#   Bounding Box: [272, 905, 433, 931]
#   Transcription: 2021.08.20
#   Class: due
#   Bounding Box: [442, 904, 496, 935]
#   Class: due
#   Bounding Box: [151, 901, 261, 934]
# Image ID: img_00095.jpg
# Height: 1372
# Width: 1029
#   Class: date
#   Bounding Box: [203, 845, 375, 870]
#   Transcription: DEC-28-2021
#   Class: due
#   Bounding Box: [142, 847, 188, 870]
# Image ID: img_00096.jpg
# Height: 1316
# Width: 987
#   Class: date
#   Bounding Box: [215, 853, 393, 876]
#   Transcription: DEC-28-2021
#   Class: due
#   Bounding Box: [148, 852, 198, 873]
# Image ID: img_00097.jpg
# Height: 1307
# Width: 980
#   Class: date
#   Bounding Box: [244, 635, 471, 657]
#   Transcription: 20/07/21
#   Class: due
#   Bounding Box: [233, 580, 287, 595]
# Image ID: img_00098.jpg
# Height: 1380
# Width: 1035
#   Class: date
#   Bounding Box: [226, 600, 411, 627]
#   Transcription: 2022.05.20
#   Class: due
#   Bounding Box: [246, 543, 317, 567]
# Image ID: img_00099.jpg
# Height: 1182
# Width: 879
#   Class: date
#   Bounding Box: [220, 755, 423, 775]
#   Transcription: MAR 04 2021
#   Class: due
#   Bounding Box: [167, 752, 200, 773]
#   Class: code
#   Bounding Box: [445, 755, 529, 774]
# Image ID: img_00100.jpg
# Height: 1186
# Width: 889
#   Class: date
#   Bounding Box: [386, 631, 497, 652]
#   Transcription: 02.18
#   Class: due
#   Bounding Box: [498, 631, 566, 653]
#   Class: code
#   Bounding Box: [385, 655, 497, 678]
# Image ID: img_00101.jpg
# Height: 1364
# Width: 1023
#   Class: date
#   Bounding Box: [429, 514, 554, 540]
#   Transcription: 02.18
#   Class: due
#   Bounding Box: [556, 514, 635, 542]
#   Class: code
#   Bounding Box: [428, 544, 552, 571]
# Image ID: img_00102.jpg
# Height: 1263
# Width: 947
#   Class: date
#   Bounding Box: [451, 537, 576, 562]
#   Transcription: 02.19
#   Class: due
#   Bounding Box: [579, 537, 651, 560]
#   Class: code
#   Bounding Box: [454, 563, 571, 589]
# Image ID: img_00103.jpg
# Height: 1270
# Width: 953
#   Class: date
#   Bounding Box: [536, 740, 659, 761]
#   Transcription: 11/08/2020
#   Class: date
#   Bounding Box: [545, 769, 664, 790]
#   Transcription: 11/11/2021
#   Class: due
#   Bounding Box: [400, 769, 471, 792]
# Image ID: img_00104.jpg
# Height: 1257
# Width: 943
#   Class: date
#   Bounding Box: [255, 394, 380, 416]
#   Transcription: 14/07/2020
#   Class: date
#   Bounding Box: [265, 422, 386, 444]
#   Transcription: 14/10/2021
#   Class: due
#   Bounding Box: [105, 422, 187, 442]
# Image ID: img_00105.jpg
# Height: 1098
# Width: 822
#   Class: date
#   Bounding Box: [221, 661, 395, 681]
#   Transcription: 07 SEP 21
#   Class: due
#   Bounding Box: [267, 642, 359, 661]
# Image ID: img_00106.jpg
# Height: 1014
# Width: 761
#   Class: date
#   Bounding Box: [282, 347, 535, 367]
#   Transcription: 2022.08.24
# Image ID: img_00107.jpg
# Height: 832
# Width: 612
#   Class: date
#   Bounding Box: [212, 443, 336, 461]
#   Transcription: 2020.08.10
#   Class: due
#   Bounding Box: [341, 447, 380, 473]
# Image ID: img_00108.jpg
# Height: 756
# Width: 1008
#   Class: date
#   Bounding Box: [334, 525, 469, 544]
#   Transcription: 2020.12.30
#   Class: date
#   Bounding Box: [335, 550, 468, 570]
#   Transcription: 2022.06.29
#   Class: due
#   Bounding Box: [468, 555, 484, 574]
# Image ID: img_00109.jpg
# Height: 891
# Width: 670
#   Class: date
#   Bounding Box: [310, 794, 424, 812]
#   Transcription: 2022.09.13
#   Class: due
#   Bounding Box: [214, 791, 293, 814]
#   Class: due
#   Bounding Box: [431, 793, 469, 815]
# Image ID: img_00110.jpg
# Height: 905
# Width: 678
#   Class: date
#   Bounding Box: [235, 657, 396, 676]
#   Transcription: 2022.11.24
# Image ID: img_00111.jpg
# Height: 703
# Width: 935
#   Class: date
#   Bounding Box: [134, 494, 231, 512]
#   Transcription: 09.08.2021
#   Class: code
#   Bounding Box: [242, 493, 291, 509]
#   Class: due
#   Bounding Box: [47, 385, 126, 407]
#   Class: due
#   Bounding Box: [94, 444, 140, 457]
# Image ID: img_00112.jpg
# Height: 704
# Width: 939
#   Class: date
#   Bounding Box: [486, 497, 603, 515]
#   Transcription: 2020.11.11
#   Class: date
#   Bounding Box: [485, 517, 601, 535]
#   Transcription: 2021.11.10
#   Class: due
#   Bounding Box: [411, 518, 452, 534]
#   Class: due
#   Bounding Box: [627, 517, 648, 530]
# Image ID: img_00113.jpg
# Height: 774
# Width: 581
#   Class: date
#   Bounding Box: [207, 483, 348, 500]
#   Transcription: 2020.01.11
#   Class: code
#   Bounding Box: [365, 481, 378, 498]
# Image ID: img_00114.jpg
# Height: 837
# Width: 625
#   Class: date
#   Bounding Box: [204, 624, 326, 642]
#   Transcription: 2023.12.27
#   Class: code
#   Bounding Box: [306, 637, 356, 658]
# Image ID: img_00115.jpg
# Height: 756
# Width: 1008
#   Class: date
#   Bounding Box: [440, 624, 546, 643]
#   Transcription: FEB/21/21
#   Class: code
#   Bounding Box: [568, 627, 624, 644]
#   Class: due
#   Bounding Box: [404, 622, 432, 644]
# Image ID: img_00116.jpg
# Height: 912
# Width: 680
#   Class: date
#   Bounding Box: [277, 424, 426, 443]
#   Transcription: 2021.05.15
#   Class: code
#   Bounding Box: [292, 442, 367, 461]
#   Class: code
#   Bounding Box: [383, 442, 410, 461]
# Image ID: img_00117.jpg
# Height: 727
# Width: 818
#   Class: date
#   Bounding Box: [309, 129, 472, 148]
#   Transcription: 2020.02.27
#   Class: due
#   Bounding Box: [273, 86, 336, 107]
#   Class: due
#   Bounding Box: [504, 157, 537, 180]
#   Class: code
#   Bounding Box: [317, 151, 398, 172]
# Image ID: img_00118.jpg
# Height: 686
# Width: 515
#   Class: date
#   Bounding Box: [173, 121, 320, 136]
#   Transcription: 2021.06.28
#   Class: code
#   Bounding Box: [210, 140, 275, 156]
#   Class: code
#   Bounding Box: [339, 123, 354, 137]
# Image ID: img_00119.jpg
# Height: 756
# Width: 1008
#   Class: date
#   Bounding Box: [511, 468, 670, 487]
#   Transcription: 13.07.2021
#   Class: due
#   Bounding Box: [398, 468, 490, 487]
#   Class: due
#   Bounding Box: [538, 437, 554, 449]
# Image ID: img_00120.jpg
# Height: 685
# Width: 900
#   Class: date
#   Bounding Box: [519, 253, 696, 274]
#   Transcription: 2020.12.09
#   Class: due
#   Bounding Box: [698, 252, 742, 273]
#   Class: due
#   Bounding Box: [484, 186, 542, 209]
#   Class: code
#   Bounding Box: [575, 233, 656, 250]
# Image ID: img_00121.jpg
# Height: 572
# Width: 741
#   Class: date
#   Bounding Box: [81, 138, 282, 155]
#   Transcription: 2020.09.08
#   Class: code
#   Bounding Box: [182, 116, 274, 132]
#   Class: due
#   Bounding Box: [257, 178, 289, 199]
# Image ID: img_00122.jpg
# Height: 756
# Width: 1008
#   Class: date
#   Bounding Box: [402, 555, 546, 576]
#   Transcription: 2021.07.07
#   Class: due
#   Bounding Box: [559, 556, 617, 577]
#   Class: due
#   Bounding Box: [298, 559, 358, 574]
#   Class: code
#   Bounding Box: [553, 522, 571, 545]
#   Class: date
#   Bounding Box: [401, 522, 540, 545]
#   Transcription: 2021.01.08
# Image ID: img_00123.jpg
# Height: 1008
# Width: 756
#   Class: date
#   Bounding Box: [397, 327, 521, 349]
#   Transcription: 10 2022
# Image ID: img_00124.jpg
# Height: 1255
# Width: 941
#   Class: date
#   Bounding Box: [130, 855, 241, 882]
#   Transcription: 2019.07.16
#   Class: due
#   Bounding Box: [242, 853, 278, 881]
#   Class: code
#   Bounding Box: [140, 885, 163, 910]
# Image ID: img_00125.jpg
# Height: 957
# Width: 717
#   Class: date
#   Bounding Box: [334, 622, 473, 643]
#   Transcription: 2021.06.28
#   Class: due
#   Bounding Box: [475, 621, 523, 645]
# Image ID: img_00126.jpg
# Height: 756
# Width: 1008
#   Class: prod
#   Bounding Box: [132, 516, 205, 539]
#   Class: due
#   Bounding Box: [132, 540, 183, 563]
#   Class: date
#   Bounding Box: [200, 542, 336, 561]
#   Transcription: 07.10.2021
#   Class: date
#   Bounding Box: [221, 518, 361, 538]
#   Transcription: 07.07.2020
#   Class: due
#   Bounding Box: [257, 448, 294, 464]
# Image ID: img_00127.jpg
# Height: 948
# Width: 564
#   Class: due
#   Bounding Box: [468, 155, 511, 178]
#   Class: date
#   Bounding Box: [288, 157, 465, 177]
#   Transcription: 2021.03.18
# Image ID: img_00128.jpg
# Height: 1008
# Width: 756
#   Class: date
#   Bounding Box: [262, 659, 405, 681]
#   Transcription: 2021.12.28
#   Class: due
#   Bounding Box: [206, 656, 247, 679]
# Image ID: img_00129.jpg
# Height: 756
# Width: 1008
#   Class: date
#   Bounding Box: [370, 479, 484, 500]
#   Transcription: 2022.04.15
#   Class: due
#   Bounding Box: [306, 479, 349, 501]
# Image ID: img_00130.jpg
# Height: 2048
# Width: 1535
#   Class: date
#   Bounding Box: [590, 1414, 844, 1466]
#   Transcription: 13.09.21
#   Class: due
#   Bounding Box: [608, 1568, 682, 1593]
# Image ID: img_00131.jpg
# Height: 902
# Width: 676
#   Class: date
#   Bounding Box: [231, 588, 357, 608]
#   Transcription: 30-04-2021
#   Class: code
#   Bounding Box: [224, 616, 240, 640]
# Image ID: img_00132.jpg
# Height: 951
# Width: 712
#   Class: date
#   Bounding Box: [413, 790, 534, 811]
#   Transcription: 07/10/2021
# Image ID: img_00133.jpg
# Height: 936
# Width: 702
#   Class: date
#   Bounding Box: [117, 544, 216, 565]
#   Transcription: 2021.05.12
# Image ID: img_00134.jpg
# Height: 981
# Width: 737
#   Class: date
#   Bounding Box: [403, 662, 531, 683]
#   Transcription: 2022.01.06
#   Class: due
#   Bounding Box: [543, 657, 577, 681]
#   Class: code
#   Bounding Box: [585, 655, 595, 675]
# Image ID: img_00135.jpg
# Height: 912
# Width: 683
#   Class: date
#   Bounding Box: [269, 694, 382, 714]
#   Transcription: 2022.12.20
#   Class: due
#   Bounding Box: [164, 675, 215, 697]
# Image ID: img_00136.jpg
# Height: 942
# Width: 705
#   Class: date
#   Bounding Box: [266, 791, 399, 812]
#   Transcription: 2022.09.01
#   Class: due
#   Bounding Box: [443, 789, 478, 813]
#   Class: due
#   Bounding Box: [149, 787, 241, 816]
# Image ID: img_00137.jpg
# Height: 756
# Width: 1008
#   Class: date
#   Bounding Box: [318, 443, 454, 463]
#   Transcription: 2022.08.10
# Image ID: img_00138.jpg
# Height: 890
# Width: 668
#   Class: date
#   Bounding Box: [368, 397, 478, 417]
#   Transcription: 2022.05.27
# Image ID: img_00139.jpg
# Height: 1008
# Width: 756
#   Class: date
#   Bounding Box: [252, 692, 399, 713]
#   Transcription: 2021.09.02
#   Class: code
#   Bounding Box: [412, 690, 436, 708]
#   Class: due
#   Bounding Box: [420, 708, 438, 727]
# Image ID: img_00140.jpg
# Height: 1008
# Width: 756
#   Class: date
#   Bounding Box: [241, 548, 380, 569]
#   Transcription: 2021.10.14
#   Class: code
#   Bounding Box: [393, 570, 461, 589]
#   Class: due
#   Bounding Box: [381, 549, 411, 568]
# Image ID: img_00141.jpg
# Height: 1008
# Width: 756
#   Class: date
#   Bounding Box: [455, 487, 571, 509]
#   Transcription: 2022.06.23
#   Class: due
#   Bounding Box: [571, 486, 591, 510]
# Image ID: img_00142.jpg
# Height: 756
# Width: 1008
#   Class: date
#   Bounding Box: [452, 334, 576, 354]
#   Transcription: 2021.01.05
#   Class: date
#   Bounding Box: [452, 357, 575, 376]
#   Transcription: 2022.07.04
#   Class: due
#   Bounding Box: [640, 357, 672, 376]
#   Class: due
#   Bounding Box: [314, 351, 350, 372]
# Image ID: img_00143.jpg
# Height: 756
# Width: 1008
#   Class: date
#   Bounding Box: [420, 339, 539, 359]
#   Transcription: 2021.01.05
#   Class: date
#   Bounding Box: [420, 360, 539, 380]
#   Transcription: 2022.01.04
#   Class: code
#   Bounding Box: [556, 342, 614, 360]
#   Class: code
#   Bounding Box: [554, 362, 613, 381]
#   Class: due
#   Bounding Box: [338, 354, 381, 378]
#   Class: due
#   Bounding Box: [620, 359, 651, 382]
# Image ID: img_00144.jpg
# Height: 910
# Width: 682
#   Class: date
#   Bounding Box: [207, 593, 310, 613]
#   Transcription: 21.11.08
# Image ID: img_00145.jpg
# Height: 954
# Width: 712
#   Class: date
#   Bounding Box: [191, 774, 316, 795]
#   Transcription: 2022.05.04
#   Class: due
#   Bounding Box: [323, 776, 357, 795]
#   Class: due
#   Bounding Box: [193, 722, 251, 743]
# Image ID: img_00146.jpg
# Height: 949
# Width: 711
#   Class: date
#   Bounding Box: [201, 686, 329, 707]
#   Transcription: 2020.12.16
# Image ID: img_00147.jpg
# Height: 957
# Width: 717
#   Class: date
#   Bounding Box: [308, 331, 451, 351]
#   Transcription: 2021.12.06
# Image ID: img_00148.jpg
# Height: 924
# Width: 692
#   Class: date
#   Bounding Box: [267, 624, 362, 644]
#   Transcription: 2022.11.02
#   Class: code
#   Bounding Box: [370, 625, 381, 645]
#   Class: due
#   Bounding Box: [194, 621, 239, 644]
#   Class: due
#   Bounding Box: [432, 617, 450, 636]
# Image ID: img_00149.jpg
# Height: 1008
# Width: 756
#   Class: date
#   Bounding Box: [260, 472, 383, 494]
#   Transcription: 2021.03.15
# Image ID: img_00150.jpg
# Height: 1008
# Width: 756
#   Class: date
#   Bounding Box: [318, 436, 387, 458]
#   Transcription: 01.24
#   Class: code
#   Bounding Box: [399, 440, 415, 459]
# Image ID: img_00151.jpg
# Height: 756
# Width: 1008
#   Class: date
#   Bounding Box: [657, 429, 776, 448]
#   Transcription: MAY 2022
#   Class: code
#   Bounding Box: [671, 450, 747, 467]
#   Class: code
#   Bounding Box: [657, 474, 697, 489]
#   Class: due
#   Bounding Box: [661, 378, 703, 390]
# Image ID: img_00152.jpg
# Height: 756
# Width: 1008
#   Class: date
#   Bounding Box: [399, 491, 513, 511]
#   Transcription: 2023/09/18
# Image ID: img_00153.jpg
# Height: 973
# Width: 729
#   Class: date
#   Bounding Box: [164, 728, 317, 748]
#   Transcription: 30/09/2021
#   Class: due
#   Bounding Box: [152, 688, 186, 701]
# Image ID: img_00154.jpg
# Height: 1008
# Width: 756
#   Class: date
#   Bounding Box: [148, 685, 324, 707]
#   Transcription: 2021.03.12
#   Class: due
#   Bounding Box: [130, 622, 164, 642]
#   Class: due
#   Bounding Box: [370, 702, 396, 715]
# Image ID: img_00155.jpg
# Height: 1269
# Width: 952
#   Class: date
#   Bounding Box: [234, 692, 380, 719]
#   Transcription: 2021.07.31
#   Class: due
#   Bounding Box: [329, 664, 445, 693]
# Image ID: img_00156.jpg
# Height: 1106
# Width: 762
#   Class: date
#   Bounding Box: [335, 569, 468, 592]
#   Transcription: 2023.09.24
#   Class: due
#   Bounding Box: [296, 565, 323, 588]
# Image ID: img_00157.jpg
# Height: 1060
# Width: 795
#   Class: date
#   Bounding Box: [314, 505, 430, 527]
#   Transcription: 21.10.13
#   Class: code
#   Bounding Box: [443, 505, 459, 527]
#   Class: due
#   Bounding Box: [498, 531, 530, 551]
# Image ID: img_00158.jpg
# Height: 1112
# Width: 834
#   Class: date
#   Bounding Box: [206, 713, 371, 738]
#   Transcription: 2021.12.07
#   Class: due
#   Bounding Box: [371, 761, 402, 781]
#   Class: due
#   Bounding Box: [78, 635, 144, 657]
#   Class: code
#   Bounding Box: [157, 715, 192, 743]
# Image ID: img_00159.jpg
# Height: 998
# Width: 785
#   Class: date
#   Bounding Box: [247, 487, 385, 507]
#   Transcription: 2021.06.17
#   Class: due
#   Bounding Box: [391, 485, 431, 505]
# Image ID: img_00160.jpg
# Height: 1051
# Width: 787
#   Class: due
#   Bounding Box: [495, 677, 527, 700]
#   Class: date
#   Bounding Box: [277, 678, 447, 701]
#   Transcription: 2021.07.09
#   Class: code
#   Bounding Box: [311, 702, 392, 724]
# Image ID: img_00161.jpg
# Height: 1093
# Width: 765
#   Class: date
#   Bounding Box: [285, 788, 428, 810]
#   Transcription: 2023.10.09
#   Class: due
#   Bounding Box: [233, 756, 270, 770]
#   Class: code
#   Bounding Box: [457, 788, 527, 810]
# Image ID: img_00162.jpg
# Height: 964
# Width: 724
#   Class: date
#   Bounding Box: [263, 340, 443, 361]
#   Transcription: 2022.06.14
# Image ID: img_00163.jpg
# Height: 977
# Width: 768
#   Class: date
#   Bounding Box: [148, 638, 263, 658]
#   Transcription: 05/08/2023
#   Class: due
#   Bounding Box: [192, 611, 249, 630]
#   Class: code
#   Bounding Box: [148, 669, 160, 687]
# Image ID: img_00164.jpg
# Height: 1230
# Width: 923
#   Class: date
#   Bounding Box: [382, 794, 504, 820]
#   Transcription: 2023.01.15
#   Class: due
#   Bounding Box: [358, 766, 417, 785]
# Image ID: img_00165.jpg
# Height: 1037
# Width: 778
#   Class: date
#   Bounding Box: [379, 323, 510, 346]
#   Transcription: 2020.07.17
#   Class: date
#   Bounding Box: [379, 348, 509, 369]
#   Transcription: 2021.04.16
#   Class: due
#   Bounding Box: [521, 346, 549, 367]
#   Class: prod
#   Bounding Box: [521, 321, 548, 344]
# Image ID: img_00166.jpg
# Height: 1080
# Width: 810
#   Class: date
#   Bounding Box: [399, 728, 504, 752]
#   Transcription: 2021.03.19
#   Class: date
#   Bounding Box: [398, 690, 505, 715]
#   Transcription: 2021.01.20
#   Class: due
#   Bounding Box: [507, 731, 539, 751]
#   Class: prod
#   Bounding Box: [507, 692, 537, 715]
# Image ID: img_00167.jpg
# Height: 1299
# Width: 974
#   Class: date
#   Bounding Box: [413, 642, 626, 668]
#   Transcription: 2021.05.25
#   Class: code
#   Bounding Box: [439, 669, 542, 696]
#   Class: code
#   Bounding Box: [564, 668, 604, 694]
# Image ID: img_00168.jpg
# Height: 1261
# Width: 946
#   Class: date
#   Bounding Box: [310, 742, 429, 769]
#   Transcription: 21.01.13
#   Class: date
#   Bounding Box: [315, 775, 431, 802]
#   Transcription: 22.01.12
#   Class: due
#   Bounding Box: [551, 774, 581, 788]
#   Class: prod
#   Bounding Box: [554, 737, 585, 753]
#   Class: due
#   Bounding Box: [265, 703, 334, 722]
#   Class: code
#   Bounding Box: [446, 741, 516, 768]
#   Class: code
#   Bounding Box: [445, 775, 459, 799]
# Image ID: img_00169.jpg
# Height: 1275
# Width: 956
#   Class: date
#   Bounding Box: [180, 764, 299, 790]
#   Transcription: 21.01.26
#   Class: date
#   Bounding Box: [181, 791, 300, 816]
#   Transcription: 21.06.25
#   Class: prod
#   Bounding Box: [414, 774, 455, 797]
#   Class: due
#   Bounding Box: [414, 814, 453, 839]
#   Class: code
#   Bounding Box: [183, 817, 243, 842]
# Image ID: img_00170.jpg
# Height: 992
# Width: 743
#   Class: date
#   Bounding Box: [157, 649, 301, 671]
#   Transcription: 2021.01.12
#   Class: date
#   Bounding Box: [157, 673, 298, 696]
#   Transcription: 2021.06.11
#   Class: due
#   Bounding Box: [316, 703, 346, 726]
#   Class: prod
#   Bounding Box: [316, 669, 346, 691]
#   Class: code
#   Bounding Box: [156, 700, 212, 722]
# Image ID: img_00171.jpg
# Height: 1056
# Width: 792
#   Class: date
#   Bounding Box: [281, 443, 401, 465]
#   Transcription: 31.10.2021
# Image ID: img_00172.jpg
# Height: 1289
# Width: 967
#   Class: date
#   Bounding Box: [389, 497, 554, 526]
#   Transcription: 2021.01.18
#   Class: date
#   Bounding Box: [389, 533, 552, 561]
#   Transcription: 2021.03.18
#   Class: prod
#   Bounding Box: [557, 495, 602, 522]
#   Class: due
#   Bounding Box: [555, 532, 598, 557]
# Image ID: img_00173.jpg
# Height: 1033
# Width: 775
#   Class: date
#   Bounding Box: [408, 249, 504, 272]
#   Transcription: 2021.01.14
#   Class: date
#   Bounding Box: [409, 276, 504, 298]
#   Transcription: 2021.03.14
#   Class: due
#   Bounding Box: [505, 275, 535, 299]
#   Class: prod
#   Bounding Box: [505, 246, 538, 273]
# Image ID: img_00174.jpg
# Height: 1200
# Width: 900
#   Class: date
#   Bounding Box: [305, 764, 492, 789]
#   Transcription: 2021.03.14
#   Class: code
#   Bounding Box: [348, 789, 436, 811]
#   Class: code
#   Bounding Box: [456, 790, 473, 812]
# Image ID: img_00175.jpg
# Height: 1066
# Width: 800
#   Class: date
#   Bounding Box: [284, 479, 445, 501]
#   Transcription: 2020.11.27
#   Class: date
#   Bounding Box: [284, 502, 445, 526]
#   Transcription: 2021.08.26
# Image ID: img_00176.jpg
# Height: 1364
# Width: 1023
#   Class: date
#   Bounding Box: [258, 462, 477, 491]
#   Transcription: 2021.03.27
#   Class: due
#   Bounding Box: [215, 407, 296, 430]
#   Class: due
#   Bounding Box: [640, 388, 679, 414]
#   Class: code
#   Bounding Box: [268, 497, 376, 524]
# Image ID: img_00177.jpg
# Height: 1169
# Width: 877
#   Class: date
#   Bounding Box: [366, 382, 499, 407]
#   Transcription: 21.02.28
#   Class: due
#   Bounding Box: [507, 382, 554, 411]
#   Class: due
#   Bounding Box: [265, 406, 320, 424]
#   Class: code
#   Bounding Box: [365, 416, 453, 443]
# Image ID: img_00178.jpg
# Height: 1231
# Width: 924
#   Class: date
#   Bounding Box: [393, 522, 525, 549]
#   Transcription: 21.03.22
#   Class: due
#   Bounding Box: [532, 524, 579, 554]
#   Class: code
#   Bounding Box: [393, 557, 480, 585]
# Image ID: img_00179.jpg
# Height: 1116
# Width: 837
#   Class: date
#   Bounding Box: [307, 756, 446, 780]
#   Transcription: 2022.09.02
# Image ID: img_00180.jpg
# Height: 1060
# Width: 795
#   Class: date
#   Bounding Box: [281, 689, 397, 711]
#   Transcription: 2022.07.12
#   Class: due
#   Bounding Box: [400, 693, 434, 717]
#   Class: code
#   Bounding Box: [369, 720, 387, 744]
#   Class: code
#   Bounding Box: [293, 722, 354, 743]
# Image ID: img_00181.jpg
# Height: 1313
# Width: 985
#   Class: date
#   Bounding Box: [351, 613, 540, 642]
#   Transcription: 2022.01.12
#   Class: due
#   Bounding Box: [553, 642, 594, 667]
#   Class: code
#   Bounding Box: [396, 647, 495, 667]
# Image ID: img_00182.jpg
# Height: 1235
# Width: 926
#   Class: date
#   Bounding Box: [339, 666, 478, 692]
#   Transcription: 2023.11.15
#   Class: code
#   Bounding Box: [484, 665, 498, 690]
# Image ID: img_00183.jpg
# Height: 1121
# Width: 841
#   Class: date
#   Bounding Box: [287, 752, 421, 777]
#   Transcription: 2022.01.12
#   Class: due
#   Bounding Box: [428, 752, 459, 778]
#   Class: code
#   Bounding Box: [376, 785, 393, 802]
# Image ID: img_00184.jpg
# Height: 1173
# Width: 879
#   Class: date
#   Bounding Box: [348, 765, 497, 790]
#   Transcription: 2022.01.20
#   Class: code
#   Bounding Box: [511, 763, 524, 787]
# Image ID: img_00185.jpg
# Height: 1027
# Width: 771
#   Class: date
#   Bounding Box: [234, 327, 349, 350]
#   Transcription: 2021.12.16
#   Class: code
#   Bounding Box: [260, 300, 317, 323]
# Image ID: img_00186.jpg
# Height: 1331
# Width: 999
#   Class: date
#   Bounding Box: [363, 894, 534, 922]
#   Transcription: 2023.01.10
# Image ID: img_00187.jpg
# Height: 1151
# Width: 863
#   Class: date
#   Bounding Box: [305, 764, 441, 789]
#   Transcription: 2022.11.17
#   Class: due
#   Bounding Box: [282, 723, 330, 749]
#   Class: due
#   Bounding Box: [486, 806, 511, 830]
#   Class: code
#   Bounding Box: [307, 792, 370, 815]
# Image ID: img_00188.jpg
# Height: 1210
# Width: 908
#   Class: date
#   Bounding Box: [235, 809, 373, 836]
#   Transcription: 09-10-2021
# Image ID: img_00189.jpg
# Height: 1263
# Width: 947
#   Class: date
#   Bounding Box: [213, 783, 368, 810]
#   Transcription: 2020.12.29
#   Class: date
#   Bounding Box: [212, 812, 366, 840]
#   Transcription: 2021.12.28
#   Class: due
#   Bounding Box: [368, 816, 417, 844]
#   Class: prod
#   Bounding Box: [370, 784, 419, 814]
#   Class: code
#   Bounding Box: [424, 791, 492, 814]
# Image ID: img_00190.jpg
# Height: 998
# Width: 749
#   Class: code
#   Bounding Box: [330, 454, 382, 473]
#   Class: due
#   Bounding Box: [258, 439, 327, 460]
#   Class: due
#   Bounding Box: [368, 444, 399, 462]
#   Class: date
#   Bounding Box: [279, 473, 380, 493]
#   Transcription: 2021.06.23
# Image ID: img_00191.jpg
# Height: 1196
# Width: 897
#   Class: date
#   Bounding Box: [311, 751, 434, 777]
#   Transcription: 20.12.11
#   Class: date
#   Bounding Box: [310, 783, 434, 809]
#   Transcription: 21.06.10
#   Class: due
#   Bounding Box: [523, 784, 557, 808]
#   Class: prod
#   Bounding Box: [523, 752, 556, 781]
#   Class: code
#   Bounding Box: [439, 760, 491, 778]
# Image ID: img_00192.jpg
# Height: 1238
# Width: 929
#   Class: date
#   Bounding Box: [294, 407, 391, 433]
#   Transcription: 02.07
#   Class: due
#   Bounding Box: [132, 408, 226, 435]
#   Class: due
#   Bounding Box: [492, 416, 536, 438]
#   Class: code
#   Bounding Box: [297, 437, 410, 464]
# Image ID: img_00193.jpg
# Height: 1214
# Width: 911
#   Class: date
#   Bounding Box: [181, 366, 279, 393]
#   Transcription: 02.12
#   Class: due
#   Bounding Box: [470, 417, 507, 438]
#   Class: due
#   Bounding Box: [161, 414, 238, 435]
#   Class: code
#   Bounding Box: [307, 364, 411, 394]
# Image ID: img_00194.jpg
# Height: 1033
# Width: 775
#   Class: date
#   Bounding Box: [327, 711, 449, 733]
#   Transcription: 21.01.12
#   Class: date
#   Bounding Box: [327, 734, 450, 757]
#   Transcription: 21.02.10
#   Class: prod
#   Bounding Box: [480, 712, 504, 728]
#   Class: due
#   Bounding Box: [481, 730, 504, 745]
#   Class: code
#   Bounding Box: [454, 722, 471, 743]
# Image ID: img_00195.jpg
# Height: 1095
# Width: 821
#   Class: date
#   Bounding Box: [364, 348, 569, 371]
#   Transcription: 2020.12.12
#   Class: date
#   Bounding Box: [365, 386, 572, 408]
#   Transcription: 2021.02.19
#   Class: due
#   Bounding Box: [320, 387, 360, 401]
#   Class: code
#   Bounding Box: [597, 390, 616, 412]
# Image ID: img_00196.jpg
# Height: 2048
# Width: 1536
#   Class: code
#   Bounding Box: [878, 1074, 991, 1115]
#   Class: date
#   Bounding Box: [557, 1075, 866, 1117]
#   Transcription: 2023.02.19
# Image ID: img_00197.jpg
# Height: 1536
# Width: 2048
#   Class: date
#   Bounding Box: [570, 515, 962, 576]
#   Transcription: 2023.09.21
# Image ID: img_00198.jpg
# Height: 1214
# Width: 910
#   Class: date
#   Bounding Box: [365, 651, 517, 677]
#   Transcription: 2023.11.01
#   Class: due
#   Bounding Box: [565, 659, 586, 673]
# Image ID: img_00199.jpg
# Height: 1112
# Width: 833
#   Class: date
#   Bounding Box: [426, 801, 540, 824]
#   Transcription: 03/03/21
#   Class: due
#   Bounding Box: [382, 803, 416, 824]
# Image ID: img_00200.jpg
# Height: 1044
# Width: 783
#   Class: date
#   Bounding Box: [373, 668, 472, 690]
#   Transcription: 24/09/2022
#   Class: due
#   Bounding Box: [302, 669, 370, 691]
# Image ID: img_00201.jpg
# Height: 1341
# Width: 1006
#   Class: date
#   Bounding Box: [521, 867, 612, 894]
#   Transcription: 17 JUL 21
#   Class: due
#   Bounding Box: [442, 870, 511, 896]
#   Class: code
#   Bounding Box: [516, 839, 568, 864]
# Image ID: img_00202.jpg
# Height: 1151
# Width: 863
#   Class: date
#   Bounding Box: [440, 401, 572, 425]
#   Transcription: 2021/10/06
# Image ID: img_00203.jpg
# Height: 1034
# Width: 776
#   Class: date
#   Bounding Box: [326, 485, 454, 507]
#   Transcription: 2021.10.23
#   Class: due
#   Bounding Box: [275, 485, 312, 507]
#   Class: code
#   Bounding Box: [355, 511, 414, 530]
# Image ID: img_00204.jpg
# Height: 1402
# Width: 1051
#   Class: date
#   Bounding Box: [401, 447, 616, 475]
#   Transcription: 2021.02.28
#   Class: code
#   Bounding Box: [444, 413, 554, 437]
# Image ID: img_00205.jpg
# Height: 1311
# Width: 983
#   Class: date
#   Bounding Box: [593, 396, 721, 425]
#   Transcription: 14.09.2020
#   Class: date
#   Bounding Box: [591, 442, 718, 470]
#   Transcription: 14.03.2022
#   Class: due
#   Bounding Box: [487, 441, 524, 471]
#   Class: code
#   Bounding Box: [696, 484, 750, 510]
# Image ID: img_00206.jpg
# Height: 910
# Width: 683
#   Class: date
#   Bounding Box: [332, 670, 410, 690]
#   Transcription: 28 JUN 21
#   Class: due
#   Bounding Box: [272, 670, 324, 689]
#   Class: code
#   Bounding Box: [322, 651, 365, 669]
# Image ID: img_00207.jpg
# Height: 949
# Width: 711
#   Class: date
#   Bounding Box: [185, 706, 359, 727]
#   Transcription: 2022.09.04
#   Class: code
#   Bounding Box: [345, 738, 427, 758]
#   Class: due
#   Bounding Box: [503, 751, 524, 768]
#   Class: due
#   Bounding Box: [74, 660, 107, 677]
# Image ID: img_00208.jpg
# Height: 756
# Width: 1008
#   Class: date
#   Bounding Box: [524, 454, 694, 478]
#   Transcription: 2021.05.25
#   Class: due
#   Bounding Box: [435, 351, 518, 376]
# Image ID: img_00209.jpg
# Height: 756
# Width: 1008
#   Class: date
#   Bounding Box: [500, 496, 610, 518]
#   Transcription: 2020.12.14
#   Class: date
#   Bounding Box: [498, 519, 610, 543]
#   Transcription: 2021.12.13
#   Class: due
#   Bounding Box: [438, 517, 467, 534]
#   Class: due
#   Bounding Box: [642, 513, 658, 531]
# Image ID: img_00210.jpg
# Height: 756
# Width: 1008
#   Class: date
#   Bounding Box: [395, 496, 538, 516]
#   Transcription: 2022.07.31
#   Class: due
#   Bounding Box: [397, 455, 443, 469]
# Image ID: img_00211.jpg
# Height: 756
# Width: 1008
#   Class: date
#   Bounding Box: [362, 466, 508, 487]
#   Transcription: 18/09/2021
#   Class: code
#   Bounding Box: [366, 489, 426, 499]
#   Class: code
#   Bounding Box: [441, 488, 479, 498]
#   Class: due
#   Bounding Box: [341, 436, 409, 453]
# Image ID: img_00212.jpg
# Height: 756
# Width: 1008
#   Class: date
#   Bounding Box: [547, 400, 670, 424]
#   Transcription: 2021/10/31
#   Class: due
#   Bounding Box: [442, 328, 486, 346]
# Image ID: img_00213.jpg
# Height: 756
# Width: 1008
#   Class: date
#   Bounding Box: [399, 498, 517, 520]
#   Transcription: 21-09-2021
# Image ID: img_00214.jpg
# Height: 838
# Width: 949
#   Class: due
#   Bounding Box: [692, 545, 735, 570]
#   Class: due
#   Bounding Box: [132, 545, 217, 571]
#   Class: date
#   Bounding Box: [270, 564, 451, 588]
#   Transcription: 21.02.07
#   Class: code
#   Bounding Box: [519, 562, 621, 585]
# Image ID: img_00215.jpg
# Height: 1194
# Width: 895
#   Class: date
#   Bounding Box: [354, 710, 512, 736]
#   Transcription: 22.01.19
#   Class: due
#   Bounding Box: [571, 706, 613, 738]
# Image ID: img_00216.jpg
# Height: 921
# Width: 1228
#   Class: date
#   Bounding Box: [460, 434, 606, 460]
#   Transcription: 2021 08 10
# ...
# Height: 1368
# Width: 1026
#   Class: date
#   Bounding Box: [168, 290, 327, 332]
#   Transcription: 15.06.2022
# Image ID: img_01022.jpg
# Height: 710
# Width: 620
#   Class: date
#   Bounding Box: [182, 99, 308, 122]
#   Transcription: 2020.12.03
#   Class: due
#   Bounding Box: [315, 103, 357, 122]
# Image ID: img_01023.jpg
# Height: 714
# Width: 567
#   Class: date
#   Bounding Box: [33, 441, 133, 468]
#   Transcription: 2020.10.29
#   Class: code
#   Bounding Box: [86, 474, 142, 499]
# Image ID: img_01024.jpg
# Height: 726
# Width: 593
#   Class: due
#   Bounding Box: [392, 335, 482, 366]
#   Class: date
#   Bounding Box: [93, 336, 381, 365]
#   Transcription: 2022.11.04
#   Class: code
#   Bounding Box: [113, 377, 252, 409]
# Image ID: img_01025.jpg
# Height: 738
# Width: 687
#   Class: date
#   Bounding Box: [465, 494, 546, 523]
#   Transcription: 04.15
#   Class: due
#   Bounding Box: [551, 494, 604, 522]
# Image ID: img_01026.jpg
# Height: 866
# Width: 656
#   Class: date
#   Bounding Box: [97, 449, 294, 482]
#   Transcription: 2020.09.06
#   Class: due
#   Bounding Box: [74, 377, 182, 408]
#   Class: due
#   Bounding Box: [279, 493, 324, 513]
#   Class: code
#   Bounding Box: [98, 488, 176, 511]
# Image ID: img_01027.jpg
# Height: 815
# Width: 702
#   Class: date
#   Bounding Box: [159, 586, 277, 617]
#   Transcription: 2022.10.23
#   Class: code
#   Bounding Box: [284, 586, 342, 615]
#   Class: due
#   Bounding Box: [350, 585, 388, 615]
#   Class: code
#   Bounding Box: [341, 551, 358, 581]
# Image ID: img_01028.jpg
# Height: 1008
# Width: 756
#   Class: due
#   Bounding Box: [361, 375, 402, 400]
#   Class: code
#   Bounding Box: [247, 325, 266, 346]
#   Class: code
#   Bounding Box: [175, 322, 240, 344]
#   Class: date
#   Bounding Box: [129, 352, 343, 391]
#   Transcription: 2021.12.29
# Image ID: img_01029.jpg
# Height: 948
# Width: 712
#   Class: date
#   Bounding Box: [366, 606, 478, 643]
#   Transcription: 2020.10.21
#   Class: date
#   Bounding Box: [366, 649, 480, 688]
#   Transcription: 2021.10.20
#   Class: due
#   Bounding Box: [483, 650, 516, 688]
#   Class: prod
#   Bounding Box: [483, 610, 516, 643]
# Image ID: img_01030.jpg
# Height: 826
# Width: 667
#   Class: date
#   Bounding Box: [172, 476, 339, 507]
#   Transcription: 2020.11.30
#   Class: code
#   Bounding Box: [205, 508, 292, 533]
#   Class: due
#   Bounding Box: [398, 513, 426, 545]
# Image ID: img_01031.jpg
# Height: 1008
# Width: 756
#   Class: date
#   Bounding Box: [271, 123, 489, 161]
#   Transcription: 2021.10.14
#   Class: due
#   Bounding Box: [178, 123, 269, 161]
# Image ID: img_01032.jpg
# Height: 1008
# Width: 756
#   Class: date
#   Bounding Box: [284, 422, 407, 461]
#   Transcription: 2021.12.16
#   Class: code
#   Bounding Box: [287, 375, 350, 414]
#   Class: code
#   Bounding Box: [398, 375, 424, 413]
# Image ID: img_01033.jpg
# Height: 1008
# Width: 756
#   Class: date
#   Bounding Box: [302, 424, 405, 463]
#   Transcription: 21.10.04
# Image ID: img_01034.jpg
# Height: 1008
# Width: 756
#   Class: date
#   Bounding Box: [222, 130, 424, 169]
#   Transcription: 2021.11.19
#   Class: code
#   Bounding Box: [246, 180, 348, 216]
#   Class: code
#   Bounding Box: [373, 182, 411, 219]
# Image ID: img_01035.jpg
# Height: 1008
# Width: 756
#   Class: date
#   Bounding Box: [287, 327, 479, 366]
#   Transcription: 2023.01.05
# Image ID: img_01036.jpg
# Height: 1008
# Width: 756
#   Class: date
#   Bounding Box: [362, 817, 532, 855]
#   Transcription: 21.12.28
#   Class: due
#   Bounding Box: [568, 844, 608, 879]
# Image ID: img_01037.jpg
# Height: 1008
# Width: 756
#   Class: date
#   Bounding Box: [349, 749, 573, 787]
#   Transcription: 2021.12.15
#   Class: due
#   Bounding Box: [594, 758, 628, 780]
#   Class: due
#   Bounding Box: [263, 738, 322, 765]
#   Class: code
#   Bounding Box: [577, 686, 605, 727]
#   Class: date
#   Bounding Box: [350, 688, 574, 731]
#   Transcription: 2020.12.16
# Image ID: img_01038.jpg
# Height: 957
# Width: 717
#   Class: date
#   Bounding Box: [285, 770, 490, 807]
#   Transcription: 2022.04.09
#   Class: due
#   Bounding Box: [180, 734, 248, 753]
# Image ID: img_01039.jpg
# Height: 869
# Width: 702
#   Class: date
#   Bounding Box: [313, 668, 386, 701]
#   Transcription: 02.12
#   Class: due
#   Bounding Box: [388, 666, 435, 699]
# Image ID: img_01040.jpg
# Height: 1033
# Width: 775
#   Class: date
#   Bounding Box: [330, 388, 509, 428]
#   Transcription: 2021.10.04
#   Class: code
#   Bounding Box: [524, 389, 544, 425]
#   Class: due
#   Bounding Box: [562, 445, 580, 465]
#   Class: due
#   Bounding Box: [267, 344, 304, 369]
# Image ID: img_01041.jpg
# Height: 1131
# Width: 999
#   Class: due
#   Bounding Box: [737, 771, 806, 819]
#   Class: date
#   Bounding Box: [276, 784, 494, 827]
#   Transcription: 19.09.11
#   Class: code
#   Bounding Box: [546, 785, 578, 818]
#   Class: code
#   Bounding Box: [526, 726, 642, 759]
#   Class: prod
#   Bounding Box: [742, 690, 808, 744]
#   Class: date
#   Bounding Box: [269, 720, 498, 768]
#   Transcription: 19.04.12
# Image ID: img_01042.jpg
# Height: 1139
# Width: 756
#   Class: date
#   Bounding Box: [273, 376, 480, 421]
#   Transcription: 2019.09.14
#   Class: code
#   Bounding Box: [500, 380, 523, 422]
# Image ID: img_01043.jpg
# Height: 1008
# Width: 756
#   Class: due
#   Bounding Box: [188, 204, 282, 243]
#   Class: date
#   Bounding Box: [284, 206, 513, 246]
#   Transcription: 2021.09.13
# Image ID: img_01044.jpg
# Height: 1200
# Width: 900
#   Class: date
#   Bounding Box: [282, 610, 503, 656]
#   Transcription: 21.10.22
#   Class: due
#   Bounding Box: [640, 596, 718, 641]
# Image ID: img_01045.jpg
# Height: 1317
# Width: 967
#   Class: date
#   Bounding Box: [385, 911, 584, 962]
#   Transcription: 2018.09.01
# Image ID: img_01046.jpg
# Height: 1351
# Width: 1013
#   Class: date
#   Bounding Box: [362, 526, 552, 579]
#   Transcription: 2021.02.12
#   Class: due
#   Bounding Box: [465, 468, 548, 495]
# Image ID: img_01047.jpg
# Height: 1274
# Width: 595
#   Class: date
#   Bounding Box: [198, 694, 425, 744]
#   Transcription: 2021.10.10
#   Class: due
#   Bounding Box: [178, 644, 289, 681]
# Image ID: img_01048.jpg
# Height: 835
# Width: 482
#   Class: date
#   Bounding Box: [114, 696, 234, 731]
#   Transcription: 2021.06.10
#   Class: due
#   Bounding Box: [235, 693, 281, 725]
# Image ID: img_01049.jpg
# Height: 775
# Width: 597
#   Class: date
#   Bounding Box: [127, 188, 303, 220]
#   Transcription: 2019.12.10
#   Class: prod
#   Bounding Box: [60, 191, 112, 221]
# Image ID: img_01050.jpg
# Height: 925
# Width: 520
#   Class: due
#   Bounding Box: [263, 521, 309, 555]
#   Class: date
#   Bounding Box: [91, 516, 261, 553]
#   Transcription: 2021.08.04
# Image ID: img_01051.jpg
# Height: 860
# Width: 673
#   Class: date
#   Bounding Box: [129, 696, 303, 733]
#   Transcription: 2021.12.22
#   Class: code
#   Bounding Box: [322, 698, 338, 729]
# Image ID: img_01052.jpg
# Height: 845
# Width: 574
#   Class: date
#   Bounding Box: [173, 134, 356, 170]
#   Transcription: 01-10-2020
# Image ID: img_01053.jpg
# Height: 927
# Width: 716
#   Class: date
#   Bounding Box: [174, 683, 402, 722]
#   Transcription: 2022.01.16
#   Class: due
#   Bounding Box: [80, 655, 144, 679]
# Image ID: img_01054.jpg
# Height: 1084
# Width: 813
#   Class: date
#   Bounding Box: [157, 513, 365, 557]
#   Transcription: 2022.05.12
#   Class: due
#   Bounding Box: [386, 503, 433, 547]
# Image ID: img_01055.jpg
# Height: 1077
# Width: 757
#   Class: date
#   Bounding Box: [189, 710, 359, 758]
#   Transcription: 05/07/2021
#   Class: code
#   Bounding Box: [377, 712, 402, 755]
# Image ID: img_01056.jpg
# Height: 1008
# Width: 756
#   Class: date
#   Bounding Box: [214, 253, 343, 297]
#   Transcription: 2022.11.12
# Image ID: img_01057.jpg
# Height: 927
# Width: 695
#   Class: date
#   Bounding Box: [237, 341, 463, 382]
#   Transcription: 2021.11.19
# Image ID: img_01058.jpg
# Height: 966
# Width: 724
#   Class: date
#   Bounding Box: [433, 163, 565, 203]
#   Transcription: 2021.12.27
# Image ID: img_01059.jpg
# Height: 1172
# Width: 623
#   Class: date
#   Bounding Box: [114, 431, 452, 480]
#   Transcription: 2019.10.28
# Image ID: img_01060.jpg
# Height: 1008
# Width: 756
#   Class: date
#   Bounding Box: [239, 767, 495, 809]
#   Transcription: 2022.12.21
#   Class: due
#   Bounding Box: [588, 782, 625, 812]
#   Class: due
#   Bounding Box: [75, 774, 141, 806]
# Image ID: img_01061.jpg
# Height: 1008
# Width: 756
#   Class: date
#   Bounding Box: [282, 297, 466, 338]
#   Transcription: 2022.10.20
#   Class: due
#   Bounding Box: [516, 306, 551, 336]
#   Class: due
#   Bounding Box: [172, 295, 248, 328]
# Image ID: img_01062.jpg
# Height: 973
# Width: 730
#   Class: date
#   Bounding Box: [273, 731, 492, 771]
#   Transcription: 2021.08.17
#   Class: due
#   Bounding Box: [504, 757, 541, 780]
#   Class: due
#   Bounding Box: [177, 704, 253, 729]
# Image ID: img_01063.jpg
# Height: 1290
# Width: 965
#   Class: due
#   Bounding Box: [705, 925, 771, 974]
#   Class: due
#   Bounding Box: [388, 571, 546, 624]
#   Class: date
#   Bounding Box: [233, 714, 527, 766]
#   Transcription: 2020.10.08
#   Class: code
#   Bounding Box: [571, 721, 707, 771]
# Image ID: img_01064.jpg
# Height: 1408
# Width: 1056
#   Class: date
#   Bounding Box: [209, 824, 515, 881]
#   Transcription: 2021.08.02
#   Class: code
#   Bounding Box: [602, 825, 652, 877]
#   Class: due
#   Bounding Box: [542, 824, 602, 873]
# Image ID: img_01065.jpg
# Height: 1200
# Width: 854
#   Class: date
#   Bounding Box: [308, 785, 522, 835]
#   Transcription: 19.08.18
#   Class: due
#   Bounding Box: [563, 784, 640, 828]
#   Class: code
#   Bounding Box: [644, 720, 745, 765]
#   Class: code
#   Bounding Box: [559, 724, 615, 764]
#   Class: date
#   Bounding Box: [310, 723, 521, 772]
#   Transcription: 19.03.19
# Image ID: img_01066.jpg
# Height: 1161
# Width: 739
#   Class: date
#   Bounding Box: [145, 864, 386, 914]
#   Transcription: 03.04.2021
# Image ID: img_01067.jpg
# Height: 544
# Width: 891
#   Class: date
#   Bounding Box: [353, 288, 544, 324]
#   Transcription: 2021.01.14
#   Class: due
#   Bounding Box: [266, 213, 347, 242]
#   Class: due
#   Bounding Box: [551, 291, 598, 325]
# Image ID: img_01068.jpg
# Height: 551
# Width: 997
#   Class: date
#   Bounding Box: [216, 68, 444, 104]
#   Transcription: FEB 04 2021
#   Class: code
#   Bounding Box: [383, 110, 458, 143]
#   Class: due
#   Bounding Box: [733, 60, 759, 84]
# Image ID: img_01069.jpg
# Height: 566
# Width: 940
#   Class: due
#   Bounding Box: [166, 307, 239, 347]
#   Class: due
#   Bounding Box: [598, 314, 633, 355]
#   Class: date
#   Bounding Box: [306, 312, 516, 349]
#   Transcription: 2021.08.04
# Image ID: img_01070.jpg
# Height: 502
# Width: 951
#   Class: date
#   Bounding Box: [493, 309, 788, 346]
#   Transcription: 2021.03.18
#   Class: code
#   Bounding Box: [641, 348, 780, 387]
#   Class: due
#   Bounding Box: [884, 335, 923, 367]
# Image ID: img_01071.jpg
# Height: 542
# Width: 898
#   Class: due
#   Bounding Box: [419, 402, 489, 420]
#   Class: date
#   Bounding Box: [556, 453, 723, 488]
#   Transcription: 2021.07.21
# Image ID: img_01072.jpg
# Height: 714
# Width: 1256
#   Class: date
#   Bounding Box: [620, 252, 904, 305]
#   Transcription: 01 JUL 2020
# Image ID: img_01073.jpg
# Height: 1117
# Width: 838
#   Class: date
#   Bounding Box: [168, 769, 327, 816]
#   Transcription: 2023/11/11
#   Class: due
#   Bounding Box: [350, 744, 397, 769]
#   Class: due
#   Bounding Box: [244, 676, 289, 703]
#   Class: due
#   Bounding Box: [141, 675, 236, 700]
# Image ID: img_01074.jpg
# Height: 1335
# Width: 1001
#   Class: date
#   Bounding Box: [287, 852, 655, 905]
#   Transcription: 2022.01.25
#   Class: due
#   Bounding Box: [788, 885, 845, 916]
# Image ID: img_01075.jpg
# Height: 1410
# Width: 1058
#   Class: date
#   Bounding Box: [414, 460, 676, 523]
#   Transcription: SEP 18 2021
# Image ID: img_01076.jpg
# Height: 1277
# Width: 958
#   Class: date
#   Bounding Box: [382, 790, 598, 839]
#   Transcription: 2023.01.05
#   Class: due
#   Bounding Box: [599, 788, 674, 832]
# Image ID: img_01077.jpg
# Height: 1443
# Width: 1082
#   Class: date
#   Bounding Box: [159, 1049, 391, 1105]
#   Transcription: 2022/11/04
# Image ID: img_01078.jpg
# Height: 1346
# Width: 1010
#   Class: date
#   Bounding Box: [402, 607, 633, 660]
#   Transcription: 02 OCT 2022
#   Class: code
#   Bounding Box: [457, 671, 574, 726]
#   Class: due
#   Bounding Box: [327, 602, 375, 656]
# Image ID: img_01079.jpg
# Height: 1308
# Width: 981
#   Class: date
#   Bounding Box: [357, 829, 570, 883]
#   Transcription: 2021.11.01
#   Class: due
#   Bounding Box: [289, 814, 325, 838]
#   Class: due
#   Bounding Box: [601, 874, 624, 899]
# Image ID: img_01080.jpg
# Height: 1288
# Width: 966
#   Class: date
#   Bounding Box: [273, 535, 424, 587]
#   Transcription: 2022.03.08
#   Class: code
#   Bounding Box: [438, 535, 516, 585]
# Image ID: img_01081.jpg
# Height: 1249
# Width: 937
#   Class: date
#   Bounding Box: [423, 536, 615, 587]
#   Transcription: 29.10.2019
#   Class: date
#   Bounding Box: [421, 599, 609, 648]
#   Transcription: 29.10.2022
#   Class: due
#   Bounding Box: [308, 598, 365, 648]
#   Class: prod
#   Bounding Box: [306, 535, 384, 588]
#   Class: code
#   Bounding Box: [632, 535, 735, 588]
# Image ID: img_01082.jpg
# Height: 1362
# Width: 1022
#   Class: date
#   Bounding Box: [413, 848, 647, 909]
#   Transcription: 2021.10.20
# Image ID: img_01083.jpg
# Height: 1316
# Width: 987
#   Class: date
#   Bounding Box: [544, 962, 711, 1018]
#   Transcription: 04.2022
# Image ID: img_01084.jpg
# Height: 1039
# Width: 1386
#   Class: date
#   Bounding Box: [867, 573, 1086, 638]
#   Transcription: 2023.01.12
#   Class: due
#   Bounding Box: [704, 525, 790, 565]
#   Class: due
#   Bounding Box: [1180, 565, 1223, 603]
# Image ID: img_01085.jpg
# Height: 1114
# Width: 825
#   Class: date
#   Bounding Box: [293, 821, 516, 866]
#   Transcription: 2023.01.18
# Image ID: img_01086.jpg
# Height: 1300
# Width: 975
#   Class: date
#   Bounding Box: [164, 911, 420, 961]
#   Transcription: 2022.07.20
#   Class: due
#   Bounding Box: [428, 910, 482, 959]
#   Class: code
#   Bounding Box: [496, 909, 545, 959]
# Image ID: img_01087.jpg
# Height: 1439
# Width: 1080
#   Class: date
#   Bounding Box: [520, 1006, 781, 1069]
#   Transcription: 2021.11.01
#   Class: due
#   Bounding Box: [799, 1006, 878, 1070]
# Image ID: img_01088.jpg
# Height: 934
# Width: 1245
#   Class: date
#   Bounding Box: [561, 529, 825, 588]
#   Transcription: 2021.12.25
# Image ID: img_01089.jpg
# Height: 1502
# Width: 1127
#   Class: date
#   Bounding Box: [346, 1104, 716, 1167]
#   Transcription: 2023.05.10
#   Class: due
#   Bounding Box: [763, 1127, 839, 1174]
# Image ID: img_01090.jpg
# Height: 608
# Width: 516
#   Class: date
#   Bounding Box: [165, 216, 364, 245]
#   Transcription: 23.10.2020
# Image ID: img_01091.jpg
# Height: 1154
# Width: 695
#   Class: date
#   Bounding Box: [283, 652, 566, 709]
#   Transcription: 2023.02.07
#   Class: due
#   Bounding Box: [248, 572, 366, 612]
# Image ID: img_01092.jpg
# Height: 886
# Width: 665
#   Class: date
#   Bounding Box: [192, 400, 463, 449]
#   Transcription: 2022/06/09
# Image ID: img_01093.jpg
# Height: 760
# Width: 585
#   Class: due
#   Bounding Box: [312, 622, 354, 661]
#   Class: date
#   Bounding Box: [150, 626, 310, 668]
#   Transcription: 2021.01.18
# Image ID: img_01094.jpg
# Height: 665
# Width: 1083
#   Class: due
#   Bounding Box: [131, 284, 241, 328]
#   Class: due
#   Bounding Box: [660, 484, 709, 524]
#   Class: date
#   Bounding Box: [208, 426, 459, 477]
#   Transcription: 20.12.23
# Image ID: img_01095.jpg
# Height: 756
# Width: 1008
#   Class: date
#   Bounding Box: [394, 474, 673, 531]
#   Transcription: 2022.07.03
# Image ID: img_01096.jpg
# Height: 1143
# Width: 857
#   Class: date
#   Bounding Box: [252, 469, 444, 532]
#   Transcription: 2021 06 11
#   Class: due
#   Bounding Box: [480, 690, 519, 723]
#   Class: code
#   Bounding Box: [332, 545, 361, 585]
# Image ID: img_01097.jpg
# Height: 1203
# Width: 902
#   Class: date
#   Bounding Box: [299, 572, 626, 639]
#   Transcription: 02 SEP 2021
#   Class: due
#   Bounding Box: [371, 492, 408, 531]
# Image ID: img_01098.jpg
# Height: 991
# Width: 777
#   Class: date
#   Bounding Box: [294, 597, 518, 642]
#   Transcription: 20.07.16
#   Class: prod
#   Bounding Box: [213, 596, 264, 640]
#   Class: code
#   Bounding Box: [543, 600, 567, 643]
# Image ID: img_01099.jpg
# Height: 1285
# Width: 1004
#   Class: date
#   Bounding Box: [381, 882, 675, 949]
#   Transcription: 2023.01.07
#   Class: due
#   Bounding Box: [178, 897, 293, 934]
#   Class: due
#   Bounding Box: [778, 890, 833, 927]
# Image ID: img_01100.jpg
# Height: 1008
# Width: 756
#   Class: date
#   Bounding Box: [272, 751, 490, 777]
#   Transcription: 03.06.2021
#   Class: due
#   Bounding Box: [201, 679, 242, 701]
# Image ID: img_01101.jpg
# Height: 613
# Width: 1009
#   Class: date
#   Bounding Box: [556, 444, 734, 471]
#   Transcription: 13/09/2020
#   Class: due
#   Bounding Box: [410, 435, 479, 458]
# Image ID: img_01102.jpg
# Height: 1507
# Width: 1131
#   Class: date
#   Bounding Box: [378, 868, 627, 906]
#   Transcription: 2022.01.26
#   Class: due
#   Bounding Box: [388, 824, 614, 859]

# %%
import json
from PIL import Image, ImageDraw
import os
import matplotlib.pyplot as plt

# Đọc file JSON
with open('../ExpirationDate/Products-Real/train/annotations.json', 'r', encoding='utf-8') as json_file:
    data = json.load(json_file)

jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00957.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00958.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00959.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00960.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00961.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00962.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00963.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00964.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00965.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00966.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00967.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00968.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00969.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00970.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00971.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00972.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00973.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00974.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00975.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00976.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00977.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00978.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00979.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00980.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00981.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00982.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00983.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00984.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00985.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00986.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00987.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00988.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00989.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00990.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00991.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00992.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00993.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00994.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00995.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00996.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00997.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00998.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_00999.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01000.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01001.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01002.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01003.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01004.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01005.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01006.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01007.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01008.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01009.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01010.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01011.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01012.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01013.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01014.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01015.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01016.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01017.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01018.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01019.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01020.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01021.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01022.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01023.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01024.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01025.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01026.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01027.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01028.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01029.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01030.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01031.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01032.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01033.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01034.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01035.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01036.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01037.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01038.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01039.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01040.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01041.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01042.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01043.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01044.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01045.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01046.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01047.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01048.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01049.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01050.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01051.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01052.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01053.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01054.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01055.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01056.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01057.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01058.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01059.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01060.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01061.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01062.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01063.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01064.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01065.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01066.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01067.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01068.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01069.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01070.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01071.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01072.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01073.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01074.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01075.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01076.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01077.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01078.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01079.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01080.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01081.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01082.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01083.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01084.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01085.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01086.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01087.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01088.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01089.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01090.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01091.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01092.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01093.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01094.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01095.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01096.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01097.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01098.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01099.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01100.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01101.jpg
# Đã xử lý và lưu: ../ExpirationDate/Products-Real/train/images\img_01102.jpg

# %%
import json
import os

def process_images(ann_file, image_dir):
    # Đọc file JSON
    with open(ann_file, 'r', encoding='utf-8') as json_file:
        data = json.load(json_file)

    # Xử lý từng ảnh trong JSON
    for img_file, img_data in data.items():
        image_path = os.path.join(image_dir, img_file)
        try:
            # Lấy thông tin từ ảnh
            image_features = img_data
            transcriptions = [entry.get("transcription", "") for entry in image_features.get("ann", [])]
            bboxes_block = [entry.get("bbox") for entry in image_features.get("ann", [])]
            categories = [entry.get("cls", "unknown") for entry in image_features.get("ann", [])]

            # Trả về thông tin ảnh
            yield {
                "id": img_file,
                "transcriptions": transcriptions,
                "bboxes_block": bboxes_block,
                "categories": categories,
                "image_path": image_path,
                "width": image_features.get("width"),
                "height": image_features.get("height"),
            }
        except Exception as e:
            print(f"Lỗi khi xử lý {img_file}: {e}")

# Sử dụng hàm
ann_file = '../ExpirationDate/Products-Real/train/annotations.json'
image_dir = '../ExpirationDate/Products-Real/train/images'

for image_info in process_images(ann_file, image_dir):
    print(image_info)
# Out:
# {'id': 'img_00001.jpg', 'transcriptions': ['2025/01/28', '', ''], 'bboxes_block': [[289, 660, 418, 673], [286, 611, 315, 626], [353, 642, 429, 657]], 'categories': ['date', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00001.jpg', 'width': 756, 'height': 1008}
# {'id': 'img_00002.jpg', 'transcriptions': ['2021/10/28', ''], 'bboxes_block': [[321, 661, 526, 675], [378, 694, 469, 707]], 'categories': ['date', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00002.jpg', 'width': 779, 'height': 1107}
# {'id': 'img_00003.jpg', 'transcriptions': ['21.05.26', '20.08.27', '', '', ''], 'bboxes_block': [[285, 767, 519, 784], [284, 747, 523, 765], [607, 772, 654, 796], [612, 733, 660, 757], [527, 767, 550, 785]], 'categories': ['date', 'date', 'due', 'prod', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00003.jpg', 'width': 947, 'height': 1263}
# {'id': 'img_00004.jpg', 'transcriptions': ['2021.03.23', '', '', ''], 'bboxes_block': [[551, 393, 758, 409], [516, 354, 571, 381], [774, 349, 802, 375], [643, 371, 740, 388]], 'categories': ['date', 'due', 'due', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00004.jpg', 'width': 1119, 'height': 839}
# {'id': 'img_00005.jpg', 'transcriptions': ['', '', '23.07.2022'], 'bboxes_block': [[538, 210, 581, 223], [503, 266, 567, 279], [450, 279, 553, 291]], 'categories': ['due', 'due', 'date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00005.jpg', 'width': 796, 'height': 603}
# {'id': 'img_00006.jpg', 'transcriptions': ['22.10.2020', '22.10.2021', '', '', ''], 'bboxes_block': [[440, 395, 588, 408], [441, 409, 582, 421], [378, 407, 423, 421], [363, 394, 423, 408], [462, 319, 497, 333]], 'categories': ['date', 'date', 'due', 'prod', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00006.jpg', 'width': 1027, 'height': 770}
# {'id': 'img_00007.jpg', 'transcriptions': ['04/03/2023', ''], 'bboxes_block': [[296, 759, 403, 775], [200, 758, 289, 774]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00007.jpg', 'width': 859, 'height': 1145}
# {'id': 'img_00008.jpg', 'transcriptions': ['29 NOV 2021', '', ''], 'bboxes_block': [[208, 255, 340, 272], [264, 219, 282, 232], [394, 256, 453, 273]], 'categories': ['date', 'due', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00008.jpg', 'width': 1014, 'height': 761}
# {'id': 'img_00009.jpg', 'transcriptions': ['25.09.2021'], 'bboxes_block': [[559, 631, 829, 650]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00009.jpg', 'width': 1342, 'height': 1006}
# {'id': 'img_00010.jpg', 'transcriptions': ['25 07 2020', '23 10 2021', '', ''], 'bboxes_block': [[516, 688, 677, 703], [515, 704, 674, 718], [327, 689, 375, 704], [327, 704, 374, 718]], 'categories': ['date', 'date', 'prod', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00010.jpg', 'width': 876, 'height': 1049}
# {'id': 'img_00011.jpg', 'transcriptions': ['15-09-2021', ''], 'bboxes_block': [[487, 357, 604, 374], [558, 375, 600, 390]], 'categories': ['date', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00011.jpg', 'width': 1008, 'height': 756}
# {'id': 'img_00012.jpg', 'transcriptions': ['15.10.2021', '', ''], 'bboxes_block': [[417, 275, 522, 292], [493, 294, 544, 311], [346, 210, 384, 229]], 'categories': ['date', 'code', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00012.jpg', 'width': 1008, 'height': 756}
# {'id': 'img_00013.jpg', 'transcriptions': ['FEB/26/21', '', ''], 'bboxes_block': [[409, 526, 508, 544], [531, 524, 585, 542], [374, 528, 400, 549]], 'categories': ['date', 'code', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00013.jpg', 'width': 1008, 'height': 756}
# {'id': 'img_00014.jpg', 'transcriptions': ['MAR 22 21', '', ''], 'bboxes_block': [[285, 580, 435, 599], [453, 582, 537, 599], [291, 553, 372, 571]], 'categories': ['date', 'code', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00014.jpg', 'width': 1234, 'height': 816}
# {'id': 'img_00015.jpg', 'transcriptions': ['2021.07.01', '', ''], 'bboxes_block': [[700, 381, 871, 401], [791, 358, 872, 378], [882, 409, 920, 434]], 'categories': ['date', 'code', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00015.jpg', 'width': 1248, 'height': 937}
# {'id': 'img_00016.jpg', 'transcriptions': ['03/04/23', ''], 'bboxes_block': [[306, 455, 393, 470], [227, 455, 296, 472]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00016.jpg', 'width': 913, 'height': 684}
# {'id': 'img_00017.jpg', 'transcriptions': ['15/07/2020', '11/05/2021', '', '', ''], 'bboxes_block': [[574, 477, 675, 495], [573, 497, 670, 514], [558, 456, 596, 470], [465, 497, 498, 514], [466, 477, 510, 495]], 'categories': ['date', 'date', 'due', 'due', 'prod'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00017.jpg', 'width': 1035, 'height': 776}
# {'id': 'img_00018.jpg', 'transcriptions': ['2021.06.08', '', '', ''], 'bboxes_block': [[488, 416, 676, 435], [682, 417, 750, 436], [379, 432, 455, 458], [587, 441, 673, 460]], 'categories': ['date', 'due', 'due', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00018.jpg', 'width': 1096, 'height': 822}
# {'id': 'img_00019.jpg', 'transcriptions': ['2021.01.04', '2021.07.03', '', ''], 'bboxes_block': [[387, 496, 579, 513], [397, 514, 588, 531], [629, 510, 669, 532], [266, 511, 346, 534]], 'categories': ['date', 'date', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00019.jpg', 'width': 1075, 'height': 793}
# {'id': 'img_00020.jpg', 'transcriptions': ['2021.07.09', '', '', ''], 'bboxes_block': [[479, 322, 688, 339], [686, 351, 712, 368], [479, 276, 535, 294], [478, 339, 582, 356]], 'categories': ['date', 'due', 'due', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00020.jpg', 'width': 1094, 'height': 808}
# {'id': 'img_00021.jpg', 'transcriptions': ['2021 12 04', ''], 'bboxes_block': [[649, 314, 881, 331], [500, 315, 625, 331]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00021.jpg', 'width': 1069, 'height': 802}
# {'id': 'img_00022.jpg', 'transcriptions': ['MAY 27 2021', ''], 'bboxes_block': [[441, 314, 642, 331], [384, 314, 421, 330]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00022.jpg', 'width': 975, 'height': 708}
# {'id': 'img_00023.jpg', 'transcriptions': ['', '', '', '2021.04.05'], 'bboxes_block': [[638, 370, 666, 394], [588, 324, 650, 343], [523, 324, 537, 343], [523, 346, 651, 366]], 'categories': ['due', 'code', 'code', 'date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00023.jpg', 'width': 1246, 'height': 935}
# {'id': 'img_00024.jpg', 'transcriptions': ['19 09 2021', '19 09 2020', '', ''], 'bboxes_block': [[887, 372, 1006, 393], [879, 339, 1000, 362], [780, 338, 853, 361], [948, 492, 1003, 510]], 'categories': ['date', 'date', 'prod', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00024.jpg', 'width': 1320, 'height': 990}
# {'id': 'img_00025.jpg', 'transcriptions': ['07 FEB 2022', '', ''], 'bboxes_block': [[261, 591, 418, 612], [373, 526, 397, 543], [490, 588, 562, 610]], 'categories': ['date', 'due', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00025.jpg', 'width': 1348, 'height': 1011}
# {'id': 'img_00026.jpg', 'transcriptions': ['2022.06.20', '', ''], 'bboxes_block': [[598, 524, 786, 548], [507, 521, 565, 549], [817, 520, 849, 546]], 'categories': ['date', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00026.jpg', 'width': 1295, 'height': 971}
# {'id': 'img_00027.jpg', 'transcriptions': ['', '2021.06.02', ''], 'bboxes_block': [[716, 328, 754, 355], [525, 306, 718, 326], [621, 284, 716, 303]], 'categories': ['due', 'date', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00027.jpg', 'width': 1266, 'height': 949}
# {'id': 'img_00028.jpg', 'transcriptions': ['2020/02/15', '2023/02/15'], 'bboxes_block': [[363, 419, 444, 433], [363, 511, 444, 525]], 'categories': ['date', 'date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00028.jpg', 'width': 948, 'height': 694}
# {'id': 'img_00029.jpg', 'transcriptions': ['01/12/21'], 'bboxes_block': [[897, 686, 1021, 709]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00029.jpg', 'width': 1399, 'height': 1049}
# {'id': 'img_00030.jpg', 'transcriptions': ['2025/05/19', '', ''], 'bboxes_block': [[377, 967, 562, 987], [469, 944, 577, 963], [353, 898, 401, 920]], 'categories': ['date', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00030.jpg', 'width': 1099, 'height': 1466}
# {'id': 'img_00031.jpg', 'transcriptions': ['2022.09.02', ''], 'bboxes_block': [[668, 794, 781, 813], [557, 793, 600, 813]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00031.jpg', 'width': 1007, 'height': 1343}
# {'id': 'img_00032.jpg', 'transcriptions': ['01/11/2021'], 'bboxes_block': [[686, 661, 821, 685]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00032.jpg', 'width': 1316, 'height': 987}
# {'id': 'img_00033.jpg', 'transcriptions': ['31-08-2021'], 'bboxes_block': [[497, 399, 646, 417]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00033.jpg', 'width': 924, 'height': 1231}
# {'id': 'img_00034.jpg', 'transcriptions': ['01.2022', ''], 'bboxes_block': [[669, 507, 804, 532], [592, 506, 650, 531]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00034.jpg', 'width': 1343, 'height': 1007}
# {'id': 'img_00035.jpg', 'transcriptions': ['01.2022', ''], 'bboxes_block': [[586, 512, 713, 536], [513, 512, 568, 535]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00035.jpg', 'width': 1333, 'height': 1000}
# {'id': 'img_00036.jpg', 'transcriptions': ['20-09-2021'], 'bboxes_block': [[284, 641, 405, 660]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00036.jpg', 'width': 669, 'height': 895}
# {'id': 'img_00037.jpg', 'transcriptions': ['2022.05.05', '', '', ''], 'bboxes_block': [[247, 765, 408, 784], [392, 787, 472, 808], [513, 808, 531, 824], [132, 732, 164, 748]], 'categories': ['date', 'code', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00037.jpg', 'width': 722, 'height': 964}
# {'id': 'img_00038.jpg', 'transcriptions': ['2021.10.19', '', ''], 'bboxes_block': [[326, 661, 532, 679], [534, 675, 564, 689], [326, 616, 398, 634]], 'categories': ['date', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00038.jpg', 'width': 756, 'height': 1008}
# {'id': 'img_00039.jpg', 'transcriptions': ['2021.07.21', '', ''], 'bboxes_block': [[353, 363, 540, 380], [380, 382, 452, 398], [312, 384, 357, 400]], 'categories': ['date', 'code', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00039.jpg', 'width': 711, 'height': 949}
# {'id': 'img_00040.jpg', 'transcriptions': ['2022.06.06', ''], 'bboxes_block': [[252, 768, 402, 786], [418, 767, 429, 786]], 'categories': ['date', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00040.jpg', 'width': 678, 'height': 905}
# {'id': 'img_00041.jpg', 'transcriptions': ['2021.09.17', ''], 'bboxes_block': [[275, 658, 406, 673], [217, 643, 257, 659]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00041.jpg', 'width': 678, 'height': 902}
# {'id': 'img_00042.jpg', 'transcriptions': ['2021.12.08', '', '', ''], 'bboxes_block': [[121, 674, 262, 691], [121, 693, 191, 709], [92, 639, 165, 660], [322, 713, 355, 731]], 'categories': ['date', 'code', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00042.jpg', 'width': 651, 'height': 872}
# {'id': 'img_00043.jpg', 'transcriptions': ['2021.12.18', '', ''], 'bboxes_block': [[398, 372, 513, 391], [439, 396, 475, 415], [479, 396, 504, 414]], 'categories': ['date', 'due', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00043.jpg', 'width': 729, 'height': 973}
# {'id': 'img_00044.jpg', 'transcriptions': ['2022.03.11'], 'bboxes_block': [[260, 749, 381, 768]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00044.jpg', 'width': 711, 'height': 962}
# {'id': 'img_00045.jpg', 'transcriptions': ['', '2022/02/26'], 'bboxes_block': [[208, 606, 249, 623], [264, 607, 405, 624]], 'categories': ['due', 'date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00045.jpg', 'width': 664, 'height': 888}
# {'id': 'img_00046.jpg', 'transcriptions': ['02.01', '', '', ''], 'bboxes_block': [[218, 241, 294, 257], [323, 238, 392, 257], [416, 273, 444, 288], [186, 273, 243, 289]], 'categories': ['date', 'code', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00046.jpg', 'width': 654, 'height': 876}
# {'id': 'img_00047.jpg', 'transcriptions': ['02.02', '', '', ''], 'bboxes_block': [[218, 312, 296, 329], [329, 313, 412, 333], [180, 348, 241, 366], [427, 351, 458, 367]], 'categories': ['date', 'code', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00047.jpg', 'width': 756, 'height': 1008}
# {'id': 'img_00048.jpg', 'transcriptions': ['2021.06.10', ''], 'bboxes_block': [[251, 488, 344, 504], [350, 486, 364, 503]], 'categories': ['date', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00048.jpg', 'width': 654, 'height': 873}
# {'id': 'img_00049.jpg', 'transcriptions': ['2021.08.23', '', ''], 'bboxes_block': [[279, 643, 448, 662], [332, 663, 414, 682], [441, 670, 472, 693]], 'categories': ['date', 'code', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00049.jpg', 'width': 756, 'height': 1008}
# {'id': 'img_00050.jpg', 'transcriptions': ['13/03/22', '', ''], 'bboxes_block': [[220, 728, 331, 746], [334, 748, 397, 766], [345, 727, 358, 745]], 'categories': ['date', 'code', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00050.jpg', 'width': 702, 'height': 939}
# {'id': 'img_00051.jpg', 'transcriptions': ['2021.10.30', ''], 'bboxes_block': [[271, 687, 364, 704], [228, 688, 259, 704]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00051.jpg', 'width': 756, 'height': 902}
# {'id': 'img_00052.jpg', 'transcriptions': ['2021.07.29', ''], 'bboxes_block': [[244, 494, 411, 512], [415, 493, 459, 509]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00052.jpg', 'width': 756, 'height': 1008}
# {'id': 'img_00053.jpg', 'transcriptions': ['2021.05.26', '', ''], 'bboxes_block': [[300, 417, 446, 433], [404, 434, 431, 453], [317, 434, 389, 452]], 'categories': ['date', 'code', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00053.jpg', 'width': 659, 'height': 879}
# {'id': 'img_00054.jpg', 'transcriptions': ['21.01.25', '21.02.10', '', ''], 'bboxes_block': [[214, 657, 345, 676], [212, 680, 343, 699], [346, 678, 383, 698], [347, 657, 384, 675]], 'categories': ['date', 'date', 'due', 'prod'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00054.jpg', 'width': 794, 'height': 1059}
# {'id': 'img_00055.jpg', 'transcriptions': ['2021.01.20', '2021.10.19'], 'bboxes_block': [[297, 400, 435, 419], [297, 421, 435, 440]], 'categories': ['date', 'date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00055.jpg', 'width': 788, 'height': 1051}
# {'id': 'img_00056.jpg', 'transcriptions': ['2022.06.11', ''], 'bboxes_block': [[258, 661, 387, 679], [402, 661, 464, 679]], 'categories': ['date', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00056.jpg', 'width': 769, 'height': 1025}
# {'id': 'img_00057.jpg', 'transcriptions': ['17.07.2022'], 'bboxes_block': [[205, 632, 323, 652]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00057.jpg', 'width': 797, 'height': 1061}
# {'id': 'img_00058.jpg', 'transcriptions': ['2021/10/28', ''], 'bboxes_block': [[247, 594, 446, 612], [303, 630, 392, 644]], 'categories': ['date', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00058.jpg', 'width': 748, 'height': 1063}
# {'id': 'img_00059.jpg', 'transcriptions': ['2021/10/28', ''], 'bboxes_block': [[284, 482, 468, 497], [335, 515, 417, 528]], 'categories': ['date', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00059.jpg', 'width': 693, 'height': 929}
# {'id': 'img_00060.jpg', 'transcriptions': ['2021 07 02', ''], 'bboxes_block': [[430, 409, 534, 428], [486, 377, 515, 395]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00060.jpg', 'width': 834, 'height': 1112}
# {'id': 'img_00061.jpg', 'transcriptions': ['29 08 2020', '29 05 2021', '', '', '', '', ''], 'bboxes_block': [[322, 321, 425, 339], [323, 345, 423, 364], [269, 343, 308, 362], [251, 319, 306, 341], [437, 322, 448, 340], [373, 471, 419, 488], [253, 467, 270, 488]], 'categories': ['date', 'date', 'due', 'prod', 'code', 'code', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00061.jpg', 'width': 794, 'height': 1058}
# {'id': 'img_00062.jpg', 'transcriptions': ['03/04/2020', '03/07/2021', '', '', ''], 'bboxes_block': [[251, 724, 419, 745], [233, 747, 391, 764], [171, 746, 217, 766], [170, 726, 233, 745], [320, 766, 381, 784]], 'categories': ['date', 'date', 'due', 'prod', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00062.jpg', 'width': 818, 'height': 1090}
# {'id': 'img_00063.jpg', 'transcriptions': ['2021 09 14', '', ''], 'bboxes_block': [[292, 659, 490, 676], [209, 657, 266, 675], [69, 564, 119, 577]], 'categories': ['date', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00063.jpg', 'width': 780, 'height': 1040}
# {'id': 'img_00064.jpg', 'transcriptions': ['2021.09.30', ''], 'bboxes_block': [[390, 304, 515, 323], [483, 325, 538, 345]], 'categories': ['date', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00064.jpg', 'width': 722, 'height': 962}
# {'id': 'img_00065.jpg', 'transcriptions': ['24/07/2020', '24/10/2021', ''], 'bboxes_block': [[495, 822, 603, 841], [503, 848, 606, 865], [383, 844, 442, 863]], 'categories': ['date', 'date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00065.jpg', 'width': 934, 'height': 1246}
# {'id': 'img_00066.jpg', 'transcriptions': ['2022.09.16', '', ''], 'bboxes_block': [[153, 367, 363, 384], [386, 365, 479, 383], [548, 365, 565, 383]], 'categories': ['date', 'code', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00066.jpg', 'width': 756, 'height': 1008}
# {'id': 'img_00067.jpg', 'transcriptions': ['2021.04.05', '', '', ''], 'bboxes_block': [[375, 471, 493, 491], [432, 442, 493, 467], [480, 496, 505, 519], [373, 442, 387, 466]], 'categories': ['date', 'code', 'due', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00067.jpg', 'width': 756, 'height': 1008}
# {'id': 'img_00068.jpg', 'transcriptions': ['2021.10.20', ''], 'bboxes_block': [[294, 758, 432, 778], [196, 764, 239, 779]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00068.jpg', 'width': 756, 'height': 1008}
# {'id': 'img_00069.jpg', 'transcriptions': ['21.02.05', '21.01.07', '', '', ''], 'bboxes_block': [[284, 935, 431, 960], [286, 906, 432, 932], [468, 910, 493, 931], [468, 880, 493, 903], [438, 921, 457, 944]], 'categories': ['date', 'date', 'due', 'prod', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00069.jpg', 'width': 953, 'height': 1271}
# {'id': 'img_00070.jpg', 'transcriptions': ['2024.03.10', ''], 'bboxes_block': [[460, 835, 583, 856], [445, 808, 498, 823]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00070.jpg', 'width': 888, 'height': 1184}
# {'id': 'img_00071.jpg', 'transcriptions': ['11 12 21', '', '', ''], 'bboxes_block': [[337, 644, 418, 666], [283, 644, 323, 668], [282, 672, 333, 692], [411, 674, 424, 692]], 'categories': ['date', 'due', 'code', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00071.jpg', 'width': 847, 'height': 1129}
# {'id': 'img_00072.jpg', 'transcriptions': ['22.01.25', '', ''], 'bboxes_block': [[270, 526, 368, 548], [494, 535, 530, 559], [378, 525, 436, 546]], 'categories': ['date', 'due', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00072.jpg', 'width': 829, 'height': 1106}
# {'id': 'img_00073.jpg', 'transcriptions': ['02.14', '', '', ''], 'bboxes_block': [[170, 294, 247, 314], [131, 335, 197, 353], [394, 338, 424, 354], [287, 297, 366, 317]], 'categories': ['date', 'due', 'due', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00073.jpg', 'width': 799, 'height': 1065}
# {'id': 'img_00074.jpg', 'transcriptions': ['21.01.29', '21.02.22', '', ''], 'bboxes_block': [[259, 732, 390, 753], [258, 754, 389, 776], [393, 729, 427, 750], [392, 752, 427, 772]], 'categories': ['date', 'date', 'prod', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00074.jpg', 'width': 846, 'height': 1127}
# {'id': 'img_00075.jpg', 'transcriptions': ['2022.07.19'], 'bboxes_block': [[318, 870, 474, 893]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00075.jpg', 'width': 892, 'height': 1189}
# {'id': 'img_00076.jpg', 'transcriptions': ['2022.01.26', '', ''], 'bboxes_block': [[357, 573, 508, 597], [248, 545, 323, 570], [557, 646, 587, 667]], 'categories': ['date', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00076.jpg', 'width': 945, 'height': 1260}
# {'id': 'img_00077.jpg', 'transcriptions': ['2023/10/21', ''], 'bboxes_block': [[366, 351, 503, 376], [367, 388, 462, 413]], 'categories': ['date', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00077.jpg', 'width': 948, 'height': 1264}
# {'id': 'img_00078.jpg', 'transcriptions': ['2023/11/14', ''], 'bboxes_block': [[215, 343, 352, 364], [217, 384, 306, 405]], 'categories': ['date', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00078.jpg', 'width': 813, 'height': 1084}
# {'id': 'img_00079.jpg', 'transcriptions': ['23.07.2021', '24.07.2020', '', ''], 'bboxes_block': [[215, 856, 392, 877], [215, 878, 393, 899], [165, 767, 220, 786], [119, 1001, 158, 1019]], 'categories': ['date', 'date', 'due', 'prod'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00079.jpg', 'width': 985, 'height': 1313}
# {'id': 'img_00080.jpg', 'transcriptions': ['02.09', '', '', ''], 'bboxes_block': [[226, 343, 343, 367], [215, 404, 304, 431], [565, 395, 610, 419], [395, 345, 480, 371]], 'categories': ['date', 'due', 'due', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00080.jpg', 'width': 995, 'height': 1327}
# {'id': 'img_00081.jpg', 'transcriptions': ['10/08/2021', ''], 'bboxes_block': [[269, 468, 437, 492], [280, 498, 290, 524]], 'categories': ['date', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00081.jpg', 'width': 1039, 'height': 1385}
# {'id': 'img_00082.jpg', 'transcriptions': ['2022.10.17', '', ''], 'bboxes_block': [[391, 941, 584, 967], [267, 943, 353, 971], [572, 973, 609, 1000]], 'categories': ['date', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00082.jpg', 'width': 1010, 'height': 1347}
# {'id': 'img_00083.jpg', 'transcriptions': ['2022/06/30', '', ''], 'bboxes_block': [[435, 881, 592, 907], [431, 923, 450, 950], [432, 963, 484, 983]], 'categories': ['date', 'code', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00083.jpg', 'width': 1019, 'height': 1358}
# {'id': 'img_00084.jpg', 'transcriptions': ['2022.01.18', '', ''], 'bboxes_block': [[125, 721, 347, 741], [399, 733, 432, 753], [349, 723, 370, 741]], 'categories': ['date', 'due', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00084.jpg', 'width': 921, 'height': 1228}
# {'id': 'img_00085.jpg', 'transcriptions': ['2021.11.11', '', ''], 'bboxes_block': [[179, 681, 405, 705], [473, 690, 511, 712], [409, 681, 431, 702]], 'categories': ['date', 'due', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00085.jpg', 'width': 941, 'height': 1255}
# {'id': 'img_00086.jpg', 'transcriptions': ['2021.06.25'], 'bboxes_block': [[265, 626, 446, 647]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00086.jpg', 'width': 909, 'height': 1211}
# {'id': 'img_00087.jpg', 'transcriptions': ['02/12/22', ''], 'bboxes_block': [[398, 619, 572, 641], [514, 599, 560, 621]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00087.jpg', 'width': 1000, 'height': 1333}
# {'id': 'img_00088.jpg', 'transcriptions': ['05.05.2020', '05.05.2022', '', ''], 'bboxes_block': [[456, 498, 561, 526], [445, 528, 550, 551], [361, 521, 388, 546], [361, 495, 399, 523]], 'categories': ['date', 'date', 'due', 'prod'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00088.jpg', 'width': 1052, 'height': 1402}
# {'id': 'img_00089.jpg', 'transcriptions': ['2023/08/03', ''], 'bboxes_block': [[230, 798, 393, 824], [228, 845, 336, 872]], 'categories': ['date', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00089.jpg', 'width': 979, 'height': 1306}
# {'id': 'img_00090.jpg', 'transcriptions': ['03 11 2020', '03 11 2021'], 'bboxes_block': [[552, 371, 704, 395], [550, 398, 702, 419]], 'categories': ['date', 'date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00090.jpg', 'width': 974, 'height': 1299}
# {'id': 'img_00091.jpg', 'transcriptions': ['2020.12.15', '2021.06.14', '', '', '', ''], 'bboxes_block': [[398, 640, 597, 664], [398, 670, 598, 695], [739, 682, 774, 712], [735, 635, 769, 665], [614, 639, 715, 663], [615, 667, 635, 692]], 'categories': ['date', 'date', 'due', 'prod', 'code', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00091.jpg', 'width': 1042, 'height': 1390}
# {'id': 'img_00092.jpg', 'transcriptions': ['2021 08 08'], 'bboxes_block': [[228, 414, 356, 436]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00092.jpg', 'width': 813, 'height': 1084}
# {'id': 'img_00093.jpg', 'transcriptions': ['15 FEB 22', '', '', ''], 'bboxes_block': [[463, 411, 568, 434], [411, 409, 443, 434], [569, 412, 584, 433], [600, 413, 676, 434]], 'categories': ['date', 'due', 'code', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00093.jpg', 'width': 1009, 'height': 1346}
# {'id': 'img_00094.jpg', 'transcriptions': ['2021.08.20', '', ''], 'bboxes_block': [[272, 905, 433, 931], [442, 904, 496, 935], [151, 901, 261, 934]], 'categories': ['date', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00094.jpg', 'width': 1045, 'height': 1393}
# {'id': 'img_00095.jpg', 'transcriptions': ['DEC-28-2021', ''], 'bboxes_block': [[203, 845, 375, 870], [142, 847, 188, 870]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00095.jpg', 'width': 1029, 'height': 1372}
# {'id': 'img_00096.jpg', 'transcriptions': ['DEC-28-2021', ''], 'bboxes_block': [[215, 853, 393, 876], [148, 852, 198, 873]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00096.jpg', 'width': 987, 'height': 1316}
# {'id': 'img_00097.jpg', 'transcriptions': ['20/07/21', ''], 'bboxes_block': [[244, 635, 471, 657], [233, 580, 287, 595]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00097.jpg', 'width': 980, 'height': 1307}
# {'id': 'img_00098.jpg', 'transcriptions': ['2022.05.20', ''], 'bboxes_block': [[226, 600, 411, 627], [246, 543, 317, 567]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00098.jpg', 'width': 1035, 'height': 1380}
# {'id': 'img_00099.jpg', 'transcriptions': ['MAR 04 2021', '', ''], 'bboxes_block': [[220, 755, 423, 775], [167, 752, 200, 773], [445, 755, 529, 774]], 'categories': ['date', 'due', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00099.jpg', 'width': 879, 'height': 1182}
# {'id': 'img_00100.jpg', 'transcriptions': ['02.18', '', ''], 'bboxes_block': [[386, 631, 497, 652], [498, 631, 566, 653], [385, 655, 497, 678]], 'categories': ['date', 'due', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00100.jpg', 'width': 889, 'height': 1186}
# {'id': 'img_00101.jpg', 'transcriptions': ['02.18', '', ''], 'bboxes_block': [[429, 514, 554, 540], [556, 514, 635, 542], [428, 544, 552, 571]], 'categories': ['date', 'due', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00101.jpg', 'width': 1023, 'height': 1364}
# {'id': 'img_00102.jpg', 'transcriptions': ['02.19', '', ''], 'bboxes_block': [[451, 537, 576, 562], [579, 537, 651, 560], [454, 563, 571, 589]], 'categories': ['date', 'due', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00102.jpg', 'width': 947, 'height': 1263}
# {'id': 'img_00103.jpg', 'transcriptions': ['11/08/2020', '11/11/2021', ''], 'bboxes_block': [[536, 740, 659, 761], [545, 769, 664, 790], [400, 769, 471, 792]], 'categories': ['date', 'date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00103.jpg', 'width': 953, 'height': 1270}
# {'id': 'img_00104.jpg', 'transcriptions': ['14/07/2020', '14/10/2021', ''], 'bboxes_block': [[255, 394, 380, 416], [265, 422, 386, 444], [105, 422, 187, 442]], 'categories': ['date', 'date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00104.jpg', 'width': 943, 'height': 1257}
# {'id': 'img_00105.jpg', 'transcriptions': ['07 SEP 21', ''], 'bboxes_block': [[221, 661, 395, 681], [267, 642, 359, 661]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00105.jpg', 'width': 822, 'height': 1098}
# {'id': 'img_00106.jpg', 'transcriptions': ['2022.08.24'], 'bboxes_block': [[282, 347, 535, 367]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00106.jpg', 'width': 761, 'height': 1014}
# {'id': 'img_00107.jpg', 'transcriptions': ['2020.08.10', ''], 'bboxes_block': [[212, 443, 336, 461], [341, 447, 380, 473]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00107.jpg', 'width': 612, 'height': 832}
# {'id': 'img_00108.jpg', 'transcriptions': ['2020.12.30', '2022.06.29', ''], 'bboxes_block': [[334, 525, 469, 544], [335, 550, 468, 570], [468, 555, 484, 574]], 'categories': ['date', 'date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00108.jpg', 'width': 1008, 'height': 756}
# {'id': 'img_00109.jpg', 'transcriptions': ['2022.09.13', '', ''], 'bboxes_block': [[310, 794, 424, 812], [214, 791, 293, 814], [431, 793, 469, 815]], 'categories': ['date', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00109.jpg', 'width': 670, 'height': 891}
# {'id': 'img_00110.jpg', 'transcriptions': ['2022.11.24'], 'bboxes_block': [[235, 657, 396, 676]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00110.jpg', 'width': 678, 'height': 905}
# {'id': 'img_00111.jpg', 'transcriptions': ['09.08.2021', '', '', ''], 'bboxes_block': [[134, 494, 231, 512], [242, 493, 291, 509], [47, 385, 126, 407], [94, 444, 140, 457]], 'categories': ['date', 'code', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00111.jpg', 'width': 935, 'height': 703}
# {'id': 'img_00112.jpg', 'transcriptions': ['2020.11.11', '2021.11.10', '', ''], 'bboxes_block': [[486, 497, 603, 515], [485, 517, 601, 535], [411, 518, 452, 534], [627, 517, 648, 530]], 'categories': ['date', 'date', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00112.jpg', 'width': 939, 'height': 704}
# {'id': 'img_00113.jpg', 'transcriptions': ['2020.01.11', ''], 'bboxes_block': [[207, 483, 348, 500], [365, 481, 378, 498]], 'categories': ['date', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00113.jpg', 'width': 581, 'height': 774}
# {'id': 'img_00114.jpg', 'transcriptions': ['2023.12.27', ''], 'bboxes_block': [[204, 624, 326, 642], [306, 637, 356, 658]], 'categories': ['date', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00114.jpg', 'width': 625, 'height': 837}
# {'id': 'img_00115.jpg', 'transcriptions': ['FEB/21/21', '', ''], 'bboxes_block': [[440, 624, 546, 643], [568, 627, 624, 644], [404, 622, 432, 644]], 'categories': ['date', 'code', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00115.jpg', 'width': 1008, 'height': 756}
# {'id': 'img_00116.jpg', 'transcriptions': ['2021.05.15', '', ''], 'bboxes_block': [[277, 424, 426, 443], [292, 442, 367, 461], [383, 442, 410, 461]], 'categories': ['date', 'code', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00116.jpg', 'width': 680, 'height': 912}
# {'id': 'img_00117.jpg', 'transcriptions': ['2020.02.27', '', '', ''], 'bboxes_block': [[309, 129, 472, 148], [273, 86, 336, 107], [504, 157, 537, 180], [317, 151, 398, 172]], 'categories': ['date', 'due', 'due', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00117.jpg', 'width': 818, 'height': 727}
# {'id': 'img_00118.jpg', 'transcriptions': ['2021.06.28', '', ''], 'bboxes_block': [[173, 121, 320, 136], [210, 140, 275, 156], [339, 123, 354, 137]], 'categories': ['date', 'code', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00118.jpg', 'width': 515, 'height': 686}
# {'id': 'img_00119.jpg', 'transcriptions': ['13.07.2021', '', ''], 'bboxes_block': [[511, 468, 670, 487], [398, 468, 490, 487], [538, 437, 554, 449]], 'categories': ['date', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00119.jpg', 'width': 1008, 'height': 756}
# {'id': 'img_00120.jpg', 'transcriptions': ['2020.12.09', '', '', ''], 'bboxes_block': [[519, 253, 696, 274], [698, 252, 742, 273], [484, 186, 542, 209], [575, 233, 656, 250]], 'categories': ['date', 'due', 'due', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00120.jpg', 'width': 900, 'height': 685}
# {'id': 'img_00121.jpg', 'transcriptions': ['2020.09.08', '', ''], 'bboxes_block': [[81, 138, 282, 155], [182, 116, 274, 132], [257, 178, 289, 199]], 'categories': ['date', 'code', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00121.jpg', 'width': 741, 'height': 572}
# {'id': 'img_00122.jpg', 'transcriptions': ['2021.07.07', '', '', '', '2021.01.08'], 'bboxes_block': [[402, 555, 546, 576], [559, 556, 617, 577], [298, 559, 358, 574], [553, 522, 571, 545], [401, 522, 540, 545]], 'categories': ['date', 'due', 'due', 'code', 'date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00122.jpg', 'width': 1008, 'height': 756}
# {'id': 'img_00123.jpg', 'transcriptions': ['10 2022'], 'bboxes_block': [[397, 327, 521, 349]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00123.jpg', 'width': 756, 'height': 1008}
# {'id': 'img_00124.jpg', 'transcriptions': ['2019.07.16', '', ''], 'bboxes_block': [[130, 855, 241, 882], [242, 853, 278, 881], [140, 885, 163, 910]], 'categories': ['date', 'due', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00124.jpg', 'width': 941, 'height': 1255}
# {'id': 'img_00125.jpg', 'transcriptions': ['2021.06.28', ''], 'bboxes_block': [[334, 622, 473, 643], [475, 621, 523, 645]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00125.jpg', 'width': 717, 'height': 957}
# {'id': 'img_00126.jpg', 'transcriptions': ['', '', '07.10.2021', '07.07.2020', ''], 'bboxes_block': [[132, 516, 205, 539], [132, 540, 183, 563], [200, 542, 336, 561], [221, 518, 361, 538], [257, 448, 294, 464]], 'categories': ['prod', 'due', 'date', 'date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00126.jpg', 'width': 1008, 'height': 756}
# {'id': 'img_00127.jpg', 'transcriptions': ['', '2021.03.18'], 'bboxes_block': [[468, 155, 511, 178], [288, 157, 465, 177]], 'categories': ['due', 'date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00127.jpg', 'width': 564, 'height': 948}
# {'id': 'img_00128.jpg', 'transcriptions': ['2021.12.28', ''], 'bboxes_block': [[262, 659, 405, 681], [206, 656, 247, 679]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00128.jpg', 'width': 756, 'height': 1008}
# {'id': 'img_00129.jpg', 'transcriptions': ['2022.04.15', ''], 'bboxes_block': [[370, 479, 484, 500], [306, 479, 349, 501]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00129.jpg', 'width': 1008, 'height': 756}
# {'id': 'img_00130.jpg', 'transcriptions': ['13.09.21', ''], 'bboxes_block': [[590, 1414, 844, 1466], [608, 1568, 682, 1593]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00130.jpg', 'width': 1535, 'height': 2048}
# {'id': 'img_00131.jpg', 'transcriptions': ['30-04-2021', ''], 'bboxes_block': [[231, 588, 357, 608], [224, 616, 240, 640]], 'categories': ['date', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00131.jpg', 'width': 676, 'height': 902}
# {'id': 'img_00132.jpg', 'transcriptions': ['07/10/2021'], 'bboxes_block': [[413, 790, 534, 811]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00132.jpg', 'width': 712, 'height': 951}
# {'id': 'img_00133.jpg', 'transcriptions': ['2021.05.12'], 'bboxes_block': [[117, 544, 216, 565]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00133.jpg', 'width': 702, 'height': 936}
# {'id': 'img_00134.jpg', 'transcriptions': ['2022.01.06', '', ''], 'bboxes_block': [[403, 662, 531, 683], [543, 657, 577, 681], [585, 655, 595, 675]], 'categories': ['date', 'due', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00134.jpg', 'width': 737, 'height': 981}
# {'id': 'img_00135.jpg', 'transcriptions': ['2022.12.20', ''], 'bboxes_block': [[269, 694, 382, 714], [164, 675, 215, 697]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00135.jpg', 'width': 683, 'height': 912}
# {'id': 'img_00136.jpg', 'transcriptions': ['2022.09.01', '', ''], 'bboxes_block': [[266, 791, 399, 812], [443, 789, 478, 813], [149, 787, 241, 816]], 'categories': ['date', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00136.jpg', 'width': 705, 'height': 942}
# {'id': 'img_00137.jpg', 'transcriptions': ['2022.08.10'], 'bboxes_block': [[318, 443, 454, 463]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00137.jpg', 'width': 1008, 'height': 756}
# {'id': 'img_00138.jpg', 'transcriptions': ['2022.05.27'], 'bboxes_block': [[368, 397, 478, 417]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00138.jpg', 'width': 668, 'height': 890}
# {'id': 'img_00139.jpg', 'transcriptions': ['2021.09.02', '', ''], 'bboxes_block': [[252, 692, 399, 713], [412, 690, 436, 708], [420, 708, 438, 727]], 'categories': ['date', 'code', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00139.jpg', 'width': 756, 'height': 1008}
# {'id': 'img_00140.jpg', 'transcriptions': ['2021.10.14', '', ''], 'bboxes_block': [[241, 548, 380, 569], [393, 570, 461, 589], [381, 549, 411, 568]], 'categories': ['date', 'code', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00140.jpg', 'width': 756, 'height': 1008}
# {'id': 'img_00141.jpg', 'transcriptions': ['2022.06.23', ''], 'bboxes_block': [[455, 487, 571, 509], [571, 486, 591, 510]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00141.jpg', 'width': 756, 'height': 1008}
# {'id': 'img_00142.jpg', 'transcriptions': ['2021.01.05', '2022.07.04', '', ''], 'bboxes_block': [[452, 334, 576, 354], [452, 357, 575, 376], [640, 357, 672, 376], [314, 351, 350, 372]], 'categories': ['date', 'date', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00142.jpg', 'width': 1008, 'height': 756}
# {'id': 'img_00143.jpg', 'transcriptions': ['2021.01.05', '2022.01.04', '', '', '', ''], 'bboxes_block': [[420, 339, 539, 359], [420, 360, 539, 380], [556, 342, 614, 360], [554, 362, 613, 381], [338, 354, 381, 378], [620, 359, 651, 382]], 'categories': ['date', 'date', 'code', 'code', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00143.jpg', 'width': 1008, 'height': 756}
# {'id': 'img_00144.jpg', 'transcriptions': ['21.11.08'], 'bboxes_block': [[207, 593, 310, 613]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00144.jpg', 'width': 682, 'height': 910}
# {'id': 'img_00145.jpg', 'transcriptions': ['2022.05.04', '', ''], 'bboxes_block': [[191, 774, 316, 795], [323, 776, 357, 795], [193, 722, 251, 743]], 'categories': ['date', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00145.jpg', 'width': 712, 'height': 954}
# {'id': 'img_00146.jpg', 'transcriptions': ['2020.12.16'], 'bboxes_block': [[201, 686, 329, 707]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00146.jpg', 'width': 711, 'height': 949}
# {'id': 'img_00147.jpg', 'transcriptions': ['2021.12.06'], 'bboxes_block': [[308, 331, 451, 351]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00147.jpg', 'width': 717, 'height': 957}
# {'id': 'img_00148.jpg', 'transcriptions': ['2022.11.02', '', '', ''], 'bboxes_block': [[267, 624, 362, 644], [370, 625, 381, 645], [194, 621, 239, 644], [432, 617, 450, 636]], 'categories': ['date', 'code', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00148.jpg', 'width': 692, 'height': 924}
# {'id': 'img_00149.jpg', 'transcriptions': ['2021.03.15'], 'bboxes_block': [[260, 472, 383, 494]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00149.jpg', 'width': 756, 'height': 1008}
# {'id': 'img_00150.jpg', 'transcriptions': ['01.24', ''], 'bboxes_block': [[318, 436, 387, 458], [399, 440, 415, 459]], 'categories': ['date', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00150.jpg', 'width': 756, 'height': 1008}
# {'id': 'img_00151.jpg', 'transcriptions': ['MAY 2022', '', '', ''], 'bboxes_block': [[657, 429, 776, 448], [671, 450, 747, 467], [657, 474, 697, 489], [661, 378, 703, 390]], 'categories': ['date', 'code', 'code', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00151.jpg', 'width': 1008, 'height': 756}
# {'id': 'img_00152.jpg', 'transcriptions': ['2023/09/18'], 'bboxes_block': [[399, 491, 513, 511]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00152.jpg', 'width': 1008, 'height': 756}
# {'id': 'img_00153.jpg', 'transcriptions': ['30/09/2021', ''], 'bboxes_block': [[164, 728, 317, 748], [152, 688, 186, 701]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00153.jpg', 'width': 729, 'height': 973}
# {'id': 'img_00154.jpg', 'transcriptions': ['2021.03.12', '', ''], 'bboxes_block': [[148, 685, 324, 707], [130, 622, 164, 642], [370, 702, 396, 715]], 'categories': ['date', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00154.jpg', 'width': 756, 'height': 1008}
# {'id': 'img_00155.jpg', 'transcriptions': ['2021.07.31', ''], 'bboxes_block': [[234, 692, 380, 719], [329, 664, 445, 693]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00155.jpg', 'width': 952, 'height': 1269}
# {'id': 'img_00156.jpg', 'transcriptions': ['2023.09.24', ''], 'bboxes_block': [[335, 569, 468, 592], [296, 565, 323, 588]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00156.jpg', 'width': 762, 'height': 1106}
# {'id': 'img_00157.jpg', 'transcriptions': ['21.10.13', '', ''], 'bboxes_block': [[314, 505, 430, 527], [443, 505, 459, 527], [498, 531, 530, 551]], 'categories': ['date', 'code', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00157.jpg', 'width': 795, 'height': 1060}
# {'id': 'img_00158.jpg', 'transcriptions': ['2021.12.07', '', '', ''], 'bboxes_block': [[206, 713, 371, 738], [371, 761, 402, 781], [78, 635, 144, 657], [157, 715, 192, 743]], 'categories': ['date', 'due', 'due', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00158.jpg', 'width': 834, 'height': 1112}
# {'id': 'img_00159.jpg', 'transcriptions': ['2021.06.17', ''], 'bboxes_block': [[247, 487, 385, 507], [391, 485, 431, 505]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00159.jpg', 'width': 785, 'height': 998}
# {'id': 'img_00160.jpg', 'transcriptions': ['', '2021.07.09', ''], 'bboxes_block': [[495, 677, 527, 700], [277, 678, 447, 701], [311, 702, 392, 724]], 'categories': ['due', 'date', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00160.jpg', 'width': 787, 'height': 1051}
# {'id': 'img_00161.jpg', 'transcriptions': ['2023.10.09', '', ''], 'bboxes_block': [[285, 788, 428, 810], [233, 756, 270, 770], [457, 788, 527, 810]], 'categories': ['date', 'due', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00161.jpg', 'width': 765, 'height': 1093}
# {'id': 'img_00162.jpg', 'transcriptions': ['2022.06.14'], 'bboxes_block': [[263, 340, 443, 361]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00162.jpg', 'width': 724, 'height': 964}
# {'id': 'img_00163.jpg', 'transcriptions': ['05/08/2023', '', ''], 'bboxes_block': [[148, 638, 263, 658], [192, 611, 249, 630], [148, 669, 160, 687]], 'categories': ['date', 'due', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00163.jpg', 'width': 768, 'height': 977}
# {'id': 'img_00164.jpg', 'transcriptions': ['2023.01.15', ''], 'bboxes_block': [[382, 794, 504, 820], [358, 766, 417, 785]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00164.jpg', 'width': 923, 'height': 1230}
# {'id': 'img_00165.jpg', 'transcriptions': ['2020.07.17', '2021.04.16', '', ''], 'bboxes_block': [[379, 323, 510, 346], [379, 348, 509, 369], [521, 346, 549, 367], [521, 321, 548, 344]], 'categories': ['date', 'date', 'due', 'prod'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00165.jpg', 'width': 778, 'height': 1037}
# {'id': 'img_00166.jpg', 'transcriptions': ['2021.03.19', '2021.01.20', '', ''], 'bboxes_block': [[399, 728, 504, 752], [398, 690, 505, 715], [507, 731, 539, 751], [507, 692, 537, 715]], 'categories': ['date', 'date', 'due', 'prod'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_00166.jpg', 'width': 810, 'height': 1080}
# ...
# {'id': 'img_01044.jpg', 'transcriptions': ['21.10.22', ''], 'bboxes_block': [[282, 610, 503, 656], [640, 596, 718, 641]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01044.jpg', 'width': 900, 'height': 1200}
# {'id': 'img_01045.jpg', 'transcriptions': ['2018.09.01'], 'bboxes_block': [[385, 911, 584, 962]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01045.jpg', 'width': 967, 'height': 1317}
# {'id': 'img_01046.jpg', 'transcriptions': ['2021.02.12', ''], 'bboxes_block': [[362, 526, 552, 579], [465, 468, 548, 495]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01046.jpg', 'width': 1013, 'height': 1351}
# {'id': 'img_01047.jpg', 'transcriptions': ['2021.10.10', ''], 'bboxes_block': [[198, 694, 425, 744], [178, 644, 289, 681]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01047.jpg', 'width': 595, 'height': 1274}
# {'id': 'img_01048.jpg', 'transcriptions': ['2021.06.10', ''], 'bboxes_block': [[114, 696, 234, 731], [235, 693, 281, 725]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01048.jpg', 'width': 482, 'height': 835}
# {'id': 'img_01049.jpg', 'transcriptions': ['2019.12.10', ''], 'bboxes_block': [[127, 188, 303, 220], [60, 191, 112, 221]], 'categories': ['date', 'prod'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01049.jpg', 'width': 597, 'height': 775}
# {'id': 'img_01050.jpg', 'transcriptions': ['', '2021.08.04'], 'bboxes_block': [[263, 521, 309, 555], [91, 516, 261, 553]], 'categories': ['due', 'date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01050.jpg', 'width': 520, 'height': 925}
# {'id': 'img_01051.jpg', 'transcriptions': ['2021.12.22', ''], 'bboxes_block': [[129, 696, 303, 733], [322, 698, 338, 729]], 'categories': ['date', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01051.jpg', 'width': 673, 'height': 860}
# {'id': 'img_01052.jpg', 'transcriptions': ['01-10-2020'], 'bboxes_block': [[173, 134, 356, 170]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01052.jpg', 'width': 574, 'height': 845}
# {'id': 'img_01053.jpg', 'transcriptions': ['2022.01.16', ''], 'bboxes_block': [[174, 683, 402, 722], [80, 655, 144, 679]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01053.jpg', 'width': 716, 'height': 927}
# {'id': 'img_01054.jpg', 'transcriptions': ['2022.05.12', ''], 'bboxes_block': [[157, 513, 365, 557], [386, 503, 433, 547]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01054.jpg', 'width': 813, 'height': 1084}
# {'id': 'img_01055.jpg', 'transcriptions': ['05/07/2021', ''], 'bboxes_block': [[189, 710, 359, 758], [377, 712, 402, 755]], 'categories': ['date', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01055.jpg', 'width': 757, 'height': 1077}
# {'id': 'img_01056.jpg', 'transcriptions': ['2022.11.12'], 'bboxes_block': [[214, 253, 343, 297]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01056.jpg', 'width': 756, 'height': 1008}
# {'id': 'img_01057.jpg', 'transcriptions': ['2021.11.19'], 'bboxes_block': [[237, 341, 463, 382]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01057.jpg', 'width': 695, 'height': 927}
# {'id': 'img_01058.jpg', 'transcriptions': ['2021.12.27'], 'bboxes_block': [[433, 163, 565, 203]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01058.jpg', 'width': 724, 'height': 966}
# {'id': 'img_01059.jpg', 'transcriptions': ['2019.10.28'], 'bboxes_block': [[114, 431, 452, 480]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01059.jpg', 'width': 623, 'height': 1172}
# {'id': 'img_01060.jpg', 'transcriptions': ['2022.12.21', '', ''], 'bboxes_block': [[239, 767, 495, 809], [588, 782, 625, 812], [75, 774, 141, 806]], 'categories': ['date', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01060.jpg', 'width': 756, 'height': 1008}
# {'id': 'img_01061.jpg', 'transcriptions': ['2022.10.20', '', ''], 'bboxes_block': [[282, 297, 466, 338], [516, 306, 551, 336], [172, 295, 248, 328]], 'categories': ['date', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01061.jpg', 'width': 756, 'height': 1008}
# {'id': 'img_01062.jpg', 'transcriptions': ['2021.08.17', '', ''], 'bboxes_block': [[273, 731, 492, 771], [504, 757, 541, 780], [177, 704, 253, 729]], 'categories': ['date', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01062.jpg', 'width': 730, 'height': 973}
# {'id': 'img_01063.jpg', 'transcriptions': ['', '', '2020.10.08', ''], 'bboxes_block': [[705, 925, 771, 974], [388, 571, 546, 624], [233, 714, 527, 766], [571, 721, 707, 771]], 'categories': ['due', 'due', 'date', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01063.jpg', 'width': 965, 'height': 1290}
# {'id': 'img_01064.jpg', 'transcriptions': ['2021.08.02', '', ''], 'bboxes_block': [[209, 824, 515, 881], [602, 825, 652, 877], [542, 824, 602, 873]], 'categories': ['date', 'code', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01064.jpg', 'width': 1056, 'height': 1408}
# {'id': 'img_01065.jpg', 'transcriptions': ['19.08.18', '', '', '', '19.03.19'], 'bboxes_block': [[308, 785, 522, 835], [563, 784, 640, 828], [644, 720, 745, 765], [559, 724, 615, 764], [310, 723, 521, 772]], 'categories': ['date', 'due', 'code', 'code', 'date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01065.jpg', 'width': 854, 'height': 1200}
# {'id': 'img_01066.jpg', 'transcriptions': ['03.04.2021'], 'bboxes_block': [[145, 864, 386, 914]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01066.jpg', 'width': 739, 'height': 1161}
# {'id': 'img_01067.jpg', 'transcriptions': ['2021.01.14', '', ''], 'bboxes_block': [[353, 288, 544, 324], [266, 213, 347, 242], [551, 291, 598, 325]], 'categories': ['date', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01067.jpg', 'width': 891, 'height': 544}
# {'id': 'img_01068.jpg', 'transcriptions': ['FEB 04 2021', '', ''], 'bboxes_block': [[216, 68, 444, 104], [383, 110, 458, 143], [733, 60, 759, 84]], 'categories': ['date', 'code', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01068.jpg', 'width': 997, 'height': 551}
# {'id': 'img_01069.jpg', 'transcriptions': ['', '', '2021.08.04'], 'bboxes_block': [[166, 307, 239, 347], [598, 314, 633, 355], [306, 312, 516, 349]], 'categories': ['due', 'due', 'date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01069.jpg', 'width': 940, 'height': 566}
# {'id': 'img_01070.jpg', 'transcriptions': ['2021.03.18', '', ''], 'bboxes_block': [[493, 309, 788, 346], [641, 348, 780, 387], [884, 335, 923, 367]], 'categories': ['date', 'code', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01070.jpg', 'width': 951, 'height': 502}
# {'id': 'img_01071.jpg', 'transcriptions': ['', '2021.07.21'], 'bboxes_block': [[419, 402, 489, 420], [556, 453, 723, 488]], 'categories': ['due', 'date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01071.jpg', 'width': 898, 'height': 542}
# {'id': 'img_01072.jpg', 'transcriptions': ['01 JUL 2020'], 'bboxes_block': [[620, 252, 904, 305]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01072.jpg', 'width': 1256, 'height': 714}
# {'id': 'img_01073.jpg', 'transcriptions': ['2023/11/11', '', '', ''], 'bboxes_block': [[168, 769, 327, 816], [350, 744, 397, 769], [244, 676, 289, 703], [141, 675, 236, 700]], 'categories': ['date', 'due', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01073.jpg', 'width': 838, 'height': 1117}
# {'id': 'img_01074.jpg', 'transcriptions': ['2022.01.25', ''], 'bboxes_block': [[287, 852, 655, 905], [788, 885, 845, 916]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01074.jpg', 'width': 1001, 'height': 1335}
# {'id': 'img_01075.jpg', 'transcriptions': ['SEP 18 2021'], 'bboxes_block': [[414, 460, 676, 523]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01075.jpg', 'width': 1058, 'height': 1410}
# {'id': 'img_01076.jpg', 'transcriptions': ['2023.01.05', ''], 'bboxes_block': [[382, 790, 598, 839], [599, 788, 674, 832]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01076.jpg', 'width': 958, 'height': 1277}
# {'id': 'img_01077.jpg', 'transcriptions': ['2022/11/04'], 'bboxes_block': [[159, 1049, 391, 1105]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01077.jpg', 'width': 1082, 'height': 1443}
# {'id': 'img_01078.jpg', 'transcriptions': ['02 OCT 2022', '', ''], 'bboxes_block': [[402, 607, 633, 660], [457, 671, 574, 726], [327, 602, 375, 656]], 'categories': ['date', 'code', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01078.jpg', 'width': 1010, 'height': 1346}
# {'id': 'img_01079.jpg', 'transcriptions': ['2021.11.01', '', ''], 'bboxes_block': [[357, 829, 570, 883], [289, 814, 325, 838], [601, 874, 624, 899]], 'categories': ['date', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01079.jpg', 'width': 981, 'height': 1308}
# {'id': 'img_01080.jpg', 'transcriptions': ['2022.03.08', ''], 'bboxes_block': [[273, 535, 424, 587], [438, 535, 516, 585]], 'categories': ['date', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01080.jpg', 'width': 966, 'height': 1288}
# {'id': 'img_01081.jpg', 'transcriptions': ['29.10.2019', '29.10.2022', '', '', ''], 'bboxes_block': [[423, 536, 615, 587], [421, 599, 609, 648], [308, 598, 365, 648], [306, 535, 384, 588], [632, 535, 735, 588]], 'categories': ['date', 'date', 'due', 'prod', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01081.jpg', 'width': 937, 'height': 1249}
# {'id': 'img_01082.jpg', 'transcriptions': ['2021.10.20'], 'bboxes_block': [[413, 848, 647, 909]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01082.jpg', 'width': 1022, 'height': 1362}
# {'id': 'img_01083.jpg', 'transcriptions': ['04.2022'], 'bboxes_block': [[544, 962, 711, 1018]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01083.jpg', 'width': 987, 'height': 1316}
# {'id': 'img_01084.jpg', 'transcriptions': ['2023.01.12', '', ''], 'bboxes_block': [[867, 573, 1086, 638], [704, 525, 790, 565], [1180, 565, 1223, 603]], 'categories': ['date', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01084.jpg', 'width': 1386, 'height': 1039}
# {'id': 'img_01085.jpg', 'transcriptions': ['2023.01.18'], 'bboxes_block': [[293, 821, 516, 866]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01085.jpg', 'width': 825, 'height': 1114}
# {'id': 'img_01086.jpg', 'transcriptions': ['2022.07.20', '', ''], 'bboxes_block': [[164, 911, 420, 961], [428, 910, 482, 959], [496, 909, 545, 959]], 'categories': ['date', 'due', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01086.jpg', 'width': 975, 'height': 1300}
# {'id': 'img_01087.jpg', 'transcriptions': ['2021.11.01', ''], 'bboxes_block': [[520, 1006, 781, 1069], [799, 1006, 878, 1070]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01087.jpg', 'width': 1080, 'height': 1439}
# {'id': 'img_01088.jpg', 'transcriptions': ['2021.12.25'], 'bboxes_block': [[561, 529, 825, 588]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01088.jpg', 'width': 1245, 'height': 934}
# {'id': 'img_01089.jpg', 'transcriptions': ['2023.05.10', ''], 'bboxes_block': [[346, 1104, 716, 1167], [763, 1127, 839, 1174]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01089.jpg', 'width': 1127, 'height': 1502}
# {'id': 'img_01090.jpg', 'transcriptions': ['23.10.2020'], 'bboxes_block': [[165, 216, 364, 245]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01090.jpg', 'width': 516, 'height': 608}
# {'id': 'img_01091.jpg', 'transcriptions': ['2023.02.07', ''], 'bboxes_block': [[283, 652, 566, 709], [248, 572, 366, 612]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01091.jpg', 'width': 695, 'height': 1154}
# {'id': 'img_01092.jpg', 'transcriptions': ['2022/06/09'], 'bboxes_block': [[192, 400, 463, 449]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01092.jpg', 'width': 665, 'height': 886}
# {'id': 'img_01093.jpg', 'transcriptions': ['', '2021.01.18'], 'bboxes_block': [[312, 622, 354, 661], [150, 626, 310, 668]], 'categories': ['due', 'date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01093.jpg', 'width': 585, 'height': 760}
# {'id': 'img_01094.jpg', 'transcriptions': ['', '', '20.12.23'], 'bboxes_block': [[131, 284, 241, 328], [660, 484, 709, 524], [208, 426, 459, 477]], 'categories': ['due', 'due', 'date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01094.jpg', 'width': 1083, 'height': 665}
# {'id': 'img_01095.jpg', 'transcriptions': ['2022.07.03'], 'bboxes_block': [[394, 474, 673, 531]], 'categories': ['date'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01095.jpg', 'width': 1008, 'height': 756}
# {'id': 'img_01096.jpg', 'transcriptions': ['2021 06 11', '', ''], 'bboxes_block': [[252, 469, 444, 532], [480, 690, 519, 723], [332, 545, 361, 585]], 'categories': ['date', 'due', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01096.jpg', 'width': 857, 'height': 1143}
# {'id': 'img_01097.jpg', 'transcriptions': ['02 SEP 2021', ''], 'bboxes_block': [[299, 572, 626, 639], [371, 492, 408, 531]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01097.jpg', 'width': 902, 'height': 1203}
# {'id': 'img_01098.jpg', 'transcriptions': ['20.07.16', '', ''], 'bboxes_block': [[294, 597, 518, 642], [213, 596, 264, 640], [543, 600, 567, 643]], 'categories': ['date', 'prod', 'code'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01098.jpg', 'width': 777, 'height': 991}
# {'id': 'img_01099.jpg', 'transcriptions': ['2023.01.07', '', ''], 'bboxes_block': [[381, 882, 675, 949], [178, 897, 293, 934], [778, 890, 833, 927]], 'categories': ['date', 'due', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01099.jpg', 'width': 1004, 'height': 1285}
# {'id': 'img_01100.jpg', 'transcriptions': ['03.06.2021', ''], 'bboxes_block': [[272, 751, 490, 777], [201, 679, 242, 701]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01100.jpg', 'width': 756, 'height': 1008}
# {'id': 'img_01101.jpg', 'transcriptions': ['13/09/2020', ''], 'bboxes_block': [[556, 444, 734, 471], [410, 435, 479, 458]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01101.jpg', 'width': 1009, 'height': 613}
# {'id': 'img_01102.jpg', 'transcriptions': ['2022.01.26', ''], 'bboxes_block': [[378, 868, 627, 906], [388, 824, 614, 859]], 'categories': ['date', 'due'], 'image_path': '../ExpirationDate/Products-Real/train/images\\img_01102.jpg', 'width': 1131, 'height': 1507}

# %%
# Xử lý từng ảnh trong JSON
for img_file, img_data in data.items():
    image_path = os.path.join(image_dir, img_file)
    try:
        with Image.open(image_path) as img:
            draw = ImageDraw.Draw(img)

            # Duyệt qua các chú thích và vẽ chữ
            for entry in img_data["ann"]:
                if "transcription" in entry:
                    bbox = entry["bbox"]
                    transcription = entry["transcription"]
                    # Vẽ chữ tại tọa độ trong bbox
                    draw.text((bbox[0], bbox[1]), transcription, fill="white")

            # Lưu ảnh đã chỉnh sửa
            modified_image_path = os.path.join(image_dir, f"modified_{img_file}")
            img.save(modified_image_path)
            print(f"Đã xử lý và lưu: {modified_image_path}")

            # Hiển thị ảnh đã nhúng
            plt.imshow(img)
            plt.axis('off')  # Tắt trục
            plt.show()
# Out:
#   Cell In[4], line 24
#     plt.show()
#               ^
# SyntaxError: incomplete input

# %%
def process_annotations(image_folder, annotations_file):
    # Đọc tệp JSON chứa nhãn
    with open(annotations_file, 'r', encoding='utf-8') as file:
        annotations = json.load(file)

    # Đánh giá mô hình trên tập dữ liệu
    for img_file, img_data in annotations.items():
        image_path = os.path.join(image_folder, img_file)
        if not os.path.exists(image_path):
            print(f"File không tồn tại: {image_path}")
            continue
        
        # Chỉ nhận diện transcription
        for annotation in img_data.get('ann', []):
            transcription = annotation.get('transcription', '')
            if transcription:
                print(f"Hình ảnh: {img_file}, Transcription: {transcription}")

                
image_folder = '../ExpirationDate/Products-Real/train/images'
annotations_file = '../ExpirationDate/Products-Real/train/annotations.json'
process_annotations(image_folder, annotations_file)
# Out:
# Hình ảnh: img_00001.jpg, Transcription: 2025/01/28
# Hình ảnh: img_00002.jpg, Transcription: 2021/10/28
# Hình ảnh: img_00003.jpg, Transcription: 21.05.26
# Hình ảnh: img_00003.jpg, Transcription: 20.08.27
# Hình ảnh: img_00004.jpg, Transcription: 2021.03.23
# Hình ảnh: img_00005.jpg, Transcription: 23.07.2022
# Hình ảnh: img_00006.jpg, Transcription: 22.10.2020
# Hình ảnh: img_00006.jpg, Transcription: 22.10.2021
# Hình ảnh: img_00007.jpg, Transcription: 04/03/2023
# Hình ảnh: img_00008.jpg, Transcription: 29 NOV 2021
# Hình ảnh: img_00009.jpg, Transcription: 25.09.2021
# Hình ảnh: img_00010.jpg, Transcription: 25 07 2020
# Hình ảnh: img_00010.jpg, Transcription: 23 10 2021
# Hình ảnh: img_00011.jpg, Transcription: 15-09-2021
# Hình ảnh: img_00012.jpg, Transcription: 15.10.2021
# Hình ảnh: img_00013.jpg, Transcription: FEB/26/21
# Hình ảnh: img_00014.jpg, Transcription: MAR 22 21
# Hình ảnh: img_00015.jpg, Transcription: 2021.07.01
# Hình ảnh: img_00016.jpg, Transcription: 03/04/23
# Hình ảnh: img_00017.jpg, Transcription: 15/07/2020
# Hình ảnh: img_00017.jpg, Transcription: 11/05/2021
# Hình ảnh: img_00018.jpg, Transcription: 2021.06.08
# Hình ảnh: img_00019.jpg, Transcription: 2021.01.04
# Hình ảnh: img_00019.jpg, Transcription: 2021.07.03
# Hình ảnh: img_00020.jpg, Transcription: 2021.07.09
# Hình ảnh: img_00021.jpg, Transcription: 2021 12 04
# Hình ảnh: img_00022.jpg, Transcription: MAY 27 2021
# Hình ảnh: img_00023.jpg, Transcription: 2021.04.05
# Hình ảnh: img_00024.jpg, Transcription: 19 09 2021
# Hình ảnh: img_00024.jpg, Transcription: 19 09 2020
# Hình ảnh: img_00025.jpg, Transcription: 07 FEB 2022
# Hình ảnh: img_00026.jpg, Transcription: 2022.06.20
# Hình ảnh: img_00027.jpg, Transcription: 2021.06.02
# Hình ảnh: img_00028.jpg, Transcription: 2020/02/15
# Hình ảnh: img_00028.jpg, Transcription: 2023/02/15
# Hình ảnh: img_00029.jpg, Transcription: 01/12/21
# Hình ảnh: img_00030.jpg, Transcription: 2025/05/19
# Hình ảnh: img_01097.jpg, Transcription: 02 SEP 2021
# Hình ảnh: img_01098.jpg, Transcription: 20.07.16
# Hình ảnh: img_01099.jpg, Transcription: 2023.01.07
# Hình ảnh: img_01100.jpg, Transcription: 03.06.2021
# Hình ảnh: img_01101.jpg, Transcription: 13/09/2020
# Hình ảnh: img_01102.jpg, Transcription: 2022.01.26

# %%
from datasets import load_dataset

dataset = load_dataset('../Test_ORC/ExpirationDate/ExpirationDate.py') 

train_data = dataset['train']
validation_data = dataset['validation']
test_data = dataset['test']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 from datasets import load_dataset
# ----> 3 dataset = load_dataset('../Test_ORC/ExpirationDate/ExpirationDate.py')
#       5 train_data = dataset['train']
#       6 validation_data = dataset['validation']
#
# File c:\Users\kienb\anaconda3\envs\kien\Lib\site-packages\datasets\load.py:2074, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2069 verification_mode = VerificationMode(
#    2070     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    2071 )
#    2073 # Create a dataset builder
# -> 2074 builder_instance = load_dataset_builder(
#    2075     path=path,
#    2076     name=name,
#    2077     data_dir=data_dir,
#    2078     data_files=data_files,
#    2079     cache_dir=cache_dir,
#    2080     features=features,
#    2081     download_config=download_config,
#    2082     download_mode=download_mode,
#    2083     revision=revision,
#    2084     token=token,
#    2085     storage_options=storage_options,
#    2086     trust_remote_code=trust_remote_code,
#    2087     _require_default_config_name=name is None,
#    2088     **config_kwargs,
#    2089 )
#    2091 # Return iterable dataset in case of streaming
#    2092 if streaming:
#
# File c:\Users\kienb\anaconda3\envs\kien\Lib\site-packages\datasets\load.py:1795, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, trust_remote_code, _require_default_config_name, **config_kwargs)
#    1793     download_config = download_config.copy() if download_config else DownloadConfig()
#    1794     download_config.storage_options.update(storage_options)
# -> 1795 dataset_module = dataset_module_factory(
#    1796     path,
#    1797     revision=revision,
#    1798     download_config=download_config,
#    1799     download_mode=download_mode,
#    1800     data_dir=data_dir,
#    1801     data_files=data_files,
#    1802     cache_dir=cache_dir,
#    1803     trust_remote_code=trust_remote_code,
#    1804     _require_default_config_name=_require_default_config_name,
#    1805     _require_custom_configs=bool(config_kwargs),
#    1806 )
#    1807 # Get dataset builder class from the processing script
#    1808 builder_kwargs = dataset_module.builder_kwargs
#
# File c:\Users\kienb\anaconda3\envs\kien\Lib\site-packages\datasets\load.py:1562, in dataset_module_factory(path, revision, download_config, download_mode, dynamic_modules_path, data_dir, data_files, cache_dir, trust_remote_code, _require_default_config_name, _require_custom_configs, **download_kwargs)
#    1555         return LocalDatasetModuleFactoryWithScript(
#    1556             path,
#    1557             download_mode=download_mode,
#    1558             dynamic_modules_path=dynamic_modules_path,
#    1559             trust_remote_code=trust_remote_code,
#    1560         ).get_module()
#    1561     else:
# -> 1562         raise FileNotFoundError(f"Couldn't find a dataset script at {relative_to_absolute_path(path)}")
#    1563 elif os.path.isfile(combined_path):
#    1564     return LocalDatasetModuleFactoryWithScript(
#    1565         combined_path,
#    1566         download_mode=download_mode,
#    1567         dynamic_modules_path=dynamic_modules_path,
#    1568         trust_remote_code=trust_remote_code,
#    1569     ).get_module()
#
# FileNotFoundError: Couldn't find a dataset script at c:\Users\kienb\Downloads\Test_ORC\Test_ORC\ExpirationDate\ExpirationDate.py

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
import json
import os

# %%
class SimpleOCR(nn.Module):
    def __init__(self, num_chars):
        super(SimpleOCR, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.fc1 = nn.Linear(64 * 7 * 7, 128)
        self.fc2 = nn.Linear(128, num_chars)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 class SimpleOCR(nn.Module):
#       2     def __init__(self, num_chars):
#       3         super(SimpleOCR, self).__init__()
#
# NameError: name 'nn' is not defined
